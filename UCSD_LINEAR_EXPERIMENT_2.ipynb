# %% [markdown]
# # Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install imutils
# !pip install lungmask
# !pip install efficientnet_pytorch
# !pip install pydicom
# !pip install --upgrade h5py
# !pip install torchxrayvision
# !pip install bokeh
# !pip install datashader
# !pip install holoviews
# !pip install colorcet
# !pip install umap-learn
# !pip install efficientnet
import efficientnet.tfkeras as efn

from __future__ import print_function
import random
import os
import numpy as np
import cv2
import pydicom as pyd
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import skimage
import torchvision

import tensorflow as tf
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.models import load_model
from keras.utils import to_categorical

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from mlxtend.plotting import plot_confusion_matrix
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.applications import ResNet50, ResNet152V2, DenseNet121
from keras.layers import (
    Dense,
    Dropout,
    Activation,
    Input,
    Flatten,
    Conv2D,
    MaxPooling2D,
    GlobalMaxPooling2D,
    BatchNormalization,
    GlobalAveragePooling2D,
)
from keras.optimizers import Adam
from keras.datasets import cifar10
from keras.preprocessing import image
from keras import regularizers
from keras.callbacks import ReduceLROnPlateau
from keras.layers import (
    Dense,
    Conv2D,
    MaxPool2D,
    Flatten,
    Dropout,
    BatchNormalization,
)
from keras.models import load_model

from imutils import paths
from PIL import Image
from skimage import (
    io,
    color,
    exposure,
    img_as_float,
    transform,
    measure,
)
from lungmask import mask as lungmask
from collections import OrderedDict
from torchvision.models import resnet50
from efficientnet_pytorch import EfficientNet
from torchvision import transforms
from pathlib import Path

# import xrv
import torchxrayvision as xrv
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import load_model
from keras import regularizers
from keras.layers import Dropout, GlobalAveragePooling2D, Flatten, Dense
import tensorflow as tf
from tensorflow.keras.layers import Layer
import numpy as np

# xrv.datasets.XRayResizer.engine = "cv2"

# !apt-get install p7zip-full
# !7z x covid_jpeg_files.zip
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Collecting lungmask
#   Downloading lungmask-0.2.18-py3-none-any.whl (19 kB)
# Collecting pydicom (from lungmask)
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lungmask) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from lungmask) (2.1.0+cu118)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lungmask) (1.11.4)
# Collecting SimpleITK (from lungmask)
#   Downloading SimpleITK-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lungmask) (4.66.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from lungmask) (0.19.3)
# Collecting fill-voids (from lungmask)
#   Downloading fill_voids-2.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.5 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lungmask) (10.1.0)
# Collecting fastremap (from fill-voids->lungmask)
#   Downloading fastremap-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 102.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->lungmask) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->lungmask) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->lungmask) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->lungmask) (1.3.0)
# Installing collected packages: SimpleITK, pydicom, fastremap, fill-voids, lungmask
# Successfully installed SimpleITK-2.3.1 fastremap-1.14.0 fill-voids-2.0.5 lungmask-0.2.18 pydicom-2.4.3
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=4c635727ff61ff7b5a48f832dd2cfecc74efd42b1c65381a78c530457f779dba
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Collecting h5py
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
# Successfully installed h5py-3.10.0
# Collecting torchxrayvision
#   Downloading torchxrayvision-1.2.1-py3-none-any.whl (29.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (0.16.0+cu118)
# Requirement already satisfied: scikit-image>=0.16 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (0.19.3)
# Requirement already satisfied: tqdm>=4 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (4.66.1)
# Requirement already satisfied: numpy>=1 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (1.23.5)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (1.5.3)
# Requirement already satisfied: requests>=1 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (2.31.0)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (9.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from torchxrayvision) (2.31.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->torchxrayvision) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->torchxrayvision) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=1->torchxrayvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=1->torchxrayvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=1->torchxrayvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=1->torchxrayvision) (2023.11.17)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16->torchxrayvision) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16->torchxrayvision) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16->torchxrayvision) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16->torchxrayvision) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16->torchxrayvision) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1->torchxrayvision) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1->torchxrayvision) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1->torchxrayvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1->torchxrayvision) (1.3.0)
# Installing collected packages: torchxrayvision
# Successfully installed torchxrayvision-1.2.1
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# Collecting datashader
#   Downloading datashader-0.16.0-py2.py3-none-any.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 55.5 MB/s eta 0:00:00
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (from datashader) (3.0.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from datashader) (2023.8.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from datashader) (1.0.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from datashader) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from datashader) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datashader) (1.5.3)
# Requirement already satisfied: param in /usr/local/lib/python3.10/dist-packages (from datashader) (2.0.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from datashader) (9.4.0)
# Requirement already satisfied: pyct in /usr/local/lib/python3.10/dist-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from datashader) (1.11.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from datashader) (2023.7.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (6.0.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask->datashader) (7.0.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->datashader) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datashader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datashader) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->datashader) (2023.11.17)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask->datashader) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datashader) (1.16.0)
# Installing collected packages: datashader
# Successfully installed datashader-0.16.0
# Requirement already satisfied: holoviews in /usr/local/lib/python3.10/dist-packages (1.17.1)
# Requirement already satisfied: param<3.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from holoviews) (2.0.1)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from holoviews) (1.23.5)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from holoviews) (3.0.0)
# Requirement already satisfied: panel>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from holoviews) (1.3.4)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (from holoviews) (3.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from holoviews) (23.2)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from holoviews) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->holoviews) (2023.3.post1)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (3.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (2023.10.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (3.5.1)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (0.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (4.66.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (6.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel>=0.13.1->holoviews) (4.5.0)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from colorcet->holoviews) (0.5.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (6.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel>=0.13.1->holoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel>=0.13.1->holoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.13.1->holoviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.13.1->holoviews) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.13.1->holoviews) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.13.1->holoviews) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->panel>=0.13.1->holoviews) (2.1.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from colorcet) (0.5.0)
# Requirement already satisfied: param>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pyct>=0.4.4->colorcet) (2.0.1)
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=91aade7847c46a9f544b818cbb944bd9329174ad296bef20b71c8e32ca05a1ff
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.10.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (23.2)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
import shutil
shutil.copy("/content/drive/MyDrive/ucsd.zip", "/content/ucsd.zip")
shutil.copy("/content/drive/MyDrive/ori.zip", "/content/ori.zip")
shutil.copy("/content/drive/MyDrive/DenseNet_224_up_uncrop.h5", "/content/DenseNet_224_up_uncrop.h5")
!7z x ucsd.zip
!7z x ori.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 22471493 bytes (22 MiB)
#
# Extracting archive: ucsd.zip
# --
# Path = ucsd.zip
# Type = zip
# Physical Size = 22471493
#
# Everything is Ok
#
# Folders: 10
# Files: 6162
# Size:       21151375
# Compressed: 22471493
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 19842873 bytes (19 MiB)
#
# Extracting archive: ori.zip
# --
# Path = ori.zip
# Type = zip
# Physical Size = 19842873
#
# Everything is Ok
#
# Folders: 10
# Files: 1662
# Size:       19522791
# Compressed: 19842873

# %%
mv "ucsd copy" "ucsd"
# Out:
# mv: cannot stat 'ucsd copy': No such file or directory

# %%
mv "ori copy" "ori"
# Out:
# mv: cannot stat 'ori copy': No such file or directory

# %% [markdown]
# # Load Data

# %%
class JPEGToNumpy():
    def __call__(self, sample):
        #print("Check Point 1")
        imagenet_mean = np.array([0.485, 0.456, 0.406])
        imagenet_std = np.array([0.229, 0.224, 0.225])
        img = image.load_img(sample['jpeg_path'], target_size=(224, 224),
                             color_mode='rgb', interpolation='lanczos')
        img_array = np.asarray(img, dtype='uint8')
        img_array =  img_array / 255
        centered = np.subtract(img_array, imagenet_mean)
        standardized = np.divide(centered, imagenet_std)
        sample['image'] = img_array
        return sample

class AiSeverity:
    def __init__(self, device=None):
        self.transforms = transforms.Compose([
            JPEGToNumpy(),
            # CreateLungMask(device),
            # ApplyLungMask(constant_values=-1024)
        ])

    def __call__(self, jpeg_path):
        sample = {'jpeg_path': jpeg_path}
        sample = self.transforms(sample)
        return sample['image']

# Folder paths
normal_folder = 'ori/Train/Negative/'
pneumonia_folder = 'ori/Train/Positive/'
# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Set the random seed for reproducibility
np.random.seed(100)

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

train_samples = file_samples
train_labels = file_labels

# Folder paths
normal_folder = 'ori/Validation/Negative/'
pneumonia_folder = 'ori/Validation/Positive/'
# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Set the random seed for reproducibility
np.random.seed(100)

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

validation_samples = file_samples
validation_labels = file_labels

# Folder paths
normal_folder = 'ori/Test/Negative/'
pneumonia_folder = 'ori/Test/Positive/'

# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

test_samples = file_samples
test_labels = file_labels

BATCH_SIZE_TRAINING = 64
BATCH_SIZE_VALIDATION = 64
BATCH_SIZE_TESTING = 1

train_datagen = ImageDataGenerator(
fill_mode="nearest",
    validation_split=0.20,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,

)

test_datagen = ImageDataGenerator(
fill_mode="nearest",
    validation_split=0.20,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
)

train_image_list = [(train_samples[key], train_labels[key]) for key in train_samples.keys()]
validation_image_list = [(validation_samples[key], validation_labels[key]) for key in validation_samples.keys()]
test_image_list = [(test_samples[key], test_labels[key]) for key in test_samples.keys()]

# Split the image_list into training and validation sets
train_generator_test = train_datagen.flow(
    x=np.array([image for image, label in train_image_list]),
    y=[label for image, label in train_image_list],
    batch_size=BATCH_SIZE_TRAINING,
    shuffle=True,
    seed=60
)

valid_generator_test = train_datagen.flow(
    x=np.array([image for image, label in validation_image_list]),
    y=[label for image, label in validation_image_list],
    batch_size=BATCH_SIZE_VALIDATION,
    shuffle=True,
    seed=60
)

test_generator_test = test_datagen.flow(
    x=np.array([image for image, label in test_image_list]),
    y=[label for image, label in test_image_list],
    batch_size=BATCH_SIZE_TESTING,
    shuffle=False,
    seed=60
)
# Out:
# ori/Train/Negative/55EK831463IZ.png: label is 0
# Index: 1
# ori/Train/Negative/8J64RMOM9Q87.png: label is 0
# Index: 2
# ori/Train/Negative/3RHYTOO25944.png: label is 0
# Index: 3
# ori/Train/Negative/H1ALFU0I0QTV.png: label is 0
# Index: 4
# ori/Train/Negative/7EOQTYGBQL6Q.png: label is 0
# Index: 5
# ori/Train/Positive/0UMNUVEEGN4T.png: label is 1
# Index: 6
# ori/Train/Positive/4WQYZGC4OCYK.png: label is 1
# Index: 7
# ori/Train/Positive/236ZF9LWBHZA.png: label is 1
# Index: 8
# ori/Train/Negative/KV2KTA5PQLXL.png: label is 0
# Index: 9
# ori/Train/Negative/HST2R9HQJSNO.png: label is 0
# Index: 10
# ori/Train/Negative/D38K93TCQRHL.png: label is 0
# Index: 11
# ori/Train/Positive/926JC47IXDOX.png: label is 1
# Index: 12
# ori/Train/Positive/2KHUUFIWHWI5.png: label is 1
# Index: 13
# ori/Train/Negative/3B6JV4KUC4KY.png: label is 0
# Index: 14
# ori/Train/Positive/0KNITUNPRZZP.png: label is 1
# Index: 15
# ori/Train/Positive/1PTFPPH58V5U.png: label is 1
# Index: 16
# ori/Train/Positive/7IW6LZNZUHF4.png: label is 1
# Index: 17
# ori/Train/Negative/7XQZ07YV49WG.png: label is 0
# Index: 18
# ori/Train/Negative/APKBDH1W9H6Y.png: label is 0
# Index: 19
# ori/Train/Positive/2L4AH1N4QZUI.png: label is 1
# Index: 20
# ori/Train/Positive/AW0T6C4DIBG3.png: label is 1
# Index: 21
# ori/Train/Positive/0ZEHOY33YTM5.png: label is 1
# Index: 22
# ori/Train/Negative/3QZLUT1VNA5K.png: label is 0
# Index: 23
# ori/Train/Positive/10CHQABJ4EN4.png: label is 1
# Index: 24
# ori/Train/Positive/DU63Q2K03TP4.png: label is 1
# Index: 25
# ori/Train/Negative/4UIYD387F0HV.png: label is 0
# Index: 26
# ori/Train/Negative/70UI2LXJOQUA.png: label is 0
# Index: 27
# ori/Train/Positive/3P6DRABOW6BC.png: label is 1
# Index: 28
# ori/Train/Positive/5TYVWUF4EAPB.png: label is 1
# Index: 29
# ori/Train/Negative/45HV643ORYSU.png: label is 0
# Index: 30
# ori/Train/Negative/KRI1BBPI277I.png: label is 0
# Index: 31
# ori/Train/Positive/0078FXVHPZZA.png: label is 1
# Index: 32
# ori/Train/Negative/CWLIJWWDM18B.png: label is 0
# Index: 33
# ori/Train/Positive/6XZYTJGC4TWH.png: label is 1
# Index: 34
# ori/Train/Negative/HQ3OKIX9BXUL.png: label is 0
# Index: 35
# ori/Train/Negative/4SGT5TMZQD7G.png: label is 0
# Index: 36
# ori/Train/Positive/92Q3L49AS27S.png: label is 1
# Index: 37
# ori/Train/Positive/9UE3QY7Q0924.png: label is 1
# Index: 38
# ori/Train/Negative/5I5GY3SF06OB.png: label is 0
# Index: 39
# ori/Train/Positive/2NV44TP6OCNN.png: label is 1
# Index: 40
# ori/Train/Negative/8UKVGWM882XW.png: label is 0
# Index: 41
# ori/Train/Negative/KY88NC8JILEF.png: label is 0
# Index: 42
# ori/Train/Negative/D19LAVFSM7IM.png: label is 0
# Index: 43
# ori/Train/Negative/KZZUZSOZM5Z2.png: label is 0
# Index: 44
# ori/Train/Positive/1G9K76LN7YIF.png: label is 1
# Index: 45
# ori/Train/Negative/K2FCVKWUPWUR.png: label is 0
# Index: 46
# ori/Train/Negative/B1X1MRK79EY9.png: label is 0
# Index: 47
# ori/Train/Positive/85IAPQ21TSJU.png: label is 1
# Index: 48
# ori/Train/Positive/9L0IQA9FXWO7.png: label is 1
# Index: 49
# ori/Train/Positive/1C7RD2GB310Q.png: label is 1
# Index: 50
# ori/Train/Negative/4RX6MO1VBO1R.png: label is 0
# Index: 51
# ori/Train/Positive/DKDQ4HOZQ84S.png: label is 1
# Index: 52
# ori/Train/Negative/FU0IG15FSC8Y.png: label is 0
# Index: 53
# ori/Train/Negative/DNU6JQJ0S2YB.png: label is 0
# Index: 54
# ori/Train/Positive/BQ7P0VFECK2X.png: label is 1
# Index: 55
# ori/Train/Positive/2V2ZHA7DU3QG.png: label is 1
# Index: 56
# ori/Train/Positive/CJY9UBOAFIAA.png: label is 1
# Index: 57
# ori/Train/Negative/2L22YFN4KEH4.png: label is 0
# Index: 58
# ori/Train/Negative/KC69J0IGSNIQ.png: label is 0
# Index: 59
# ori/Train/Positive/36GCGKERPE5P.png: label is 1
# Index: 60
# ori/Train/Negative/C9EAWCEQ8Z05.png: label is 0
# Index: 61
# ori/Train/Positive/A0PR1DB5OLV7.png: label is 1
# Index: 62
# ori/Train/Negative/5I9GKDIXWFLN.png: label is 0
# Index: 63
# ori/Train/Positive/0BTRPRBAC5VC.png: label is 1
# Index: 64
# ori/Train/Positive/0HWQQLA0E8ID.png: label is 1
# Index: 65
# ori/Train/Positive/0A12B23E9EOL.png: label is 1
# Index: 66
# ori/Train/Positive/1POGJY0CX90D.png: label is 1
# Index: 67
# ori/Train/Positive/BS9W67CGZHT0.png: label is 1
# Index: 68
# ori/Train/Negative/5OLX7IUSHRO2.png: label is 0
# Index: 69
# ori/Train/Negative/7THLTQLH7UOS.png: label is 0
# Index: 70
# ori/Train/Negative/B9WLNGH1WMIN.png: label is 0
# Index: 71
# ori/Train/Negative/JP7QAHMOLD48.png: label is 0
# Index: 72
# ori/Train/Negative/FR0TGW926CD4.png: label is 0
# Index: 73
# ori/Train/Positive/96ULBMB8DK85.png: label is 1
# Index: 74
# ori/Train/Negative/FGKFJPCZ2CDN.png: label is 0
# Index: 75
# ori/Train/Negative/4W3VTUKQJ6H9.png: label is 0
# Index: 76
# ori/Train/Positive/54DERU5DC23J.png: label is 1
# Index: 77
# ori/Train/Negative/6W6H2567D7EM.png: label is 0
# Index: 78
# ori/Train/Positive/F9T31KBIGGE4.png: label is 1
# Index: 79
# ori/Train/Positive/BVXWXJOB4CD7.png: label is 1
# Index: 80
# ori/Train/Positive/0NRS7BU044E7.png: label is 1
# Index: 81
# ori/Train/Negative/FEF9SIV1JVUK.png: label is 0
# Index: 82
# ori/Train/Negative/54VXFS6FHT8R.png: label is 0
# Index: 83
# ori/Train/Negative/42B2I9D8A6YY.png: label is 0
# Index: 84
# ori/Train/Negative/HBULJARSUDZ3.png: label is 0
# Index: 85
# ori/Train/Positive/D9JH5WVS8O0H.png: label is 1
# Index: 86
# ori/Train/Positive/2KMAJT8RMFID.png: label is 1
# Index: 87
# ori/Train/Negative/8PHQPNRF4NFY.png: label is 0
# Index: 88
# ori/Train/Positive/5S1FI6EBKTAG.png: label is 1
# Index: 89
# ori/Train/Positive/9MR6Q0WFKLAS.png: label is 1
# Index: 90
# ori/Train/Negative/726LVPO3JWJ2.png: label is 0
# Index: 91
# ori/Train/Positive/BRO6V81JK01N.png: label is 1
# Index: 92
# ori/Train/Positive/EBA3ISYFCVQF.png: label is 1
# Index: 93
# ori/Train/Negative/JGV3UB800XCJ.png: label is 0
# Index: 94
# ori/Train/Positive/8UE9BUI4QK9I.png: label is 1
# Index: 95
# ori/Train/Negative/FFWA90F8B2NE.png: label is 0
# Index: 96
# ori/Train/Negative/G0REIV8TKWN7.png: label is 0
# Index: 97
# ori/Train/Positive/25QG0T6UIHH5.png: label is 1
# Index: 98
# ori/Train/Negative/48B1HC65JSN9.png: label is 0
# Index: 99
# ori/Train/Positive/3FRK0N7PJIIJ.png: label is 1
# Index: 100
# ori/Train/Positive/AW6HU698K7KN.png: label is 1
# Index: 101
# ori/Train/Positive/7KLULN5BXMRA.png: label is 1
# Index: 102
# ori/Train/Negative/DJG1WDD8CY9V.png: label is 0
# Index: 103
# ori/Train/Negative/J7CD9Q2QB39Q.png: label is 0
# Index: 104
# ori/Train/Negative/9OK5UJ8FZPT7.png: label is 0
# Index: 105
# ori/Train/Negative/BFMCFT7TDRBJ.png: label is 0
# Index: 106
# ori/Train/Negative/90F9PC3LQ6LO.png: label is 0
# Index: 107
# ori/Train/Negative/5KULNN39TFD7.png: label is 0
# Index: 108
# ori/Train/Negative/IB92VWVP48WN.png: label is 0
# Index: 109
# ori/Train/Positive/CZEFAYE0FKHP.png: label is 1
# Index: 110
# ori/Train/Positive/56FU2C1TQ8G7.png: label is 1
# Index: 111
# ori/Train/Positive/0H8RJNXOB5M2.png: label is 1
# Index: 112
# ori/Train/Positive/1J207NN7Y2L2.png: label is 1
# Index: 113
# ori/Train/Positive/35GZ22LYDRLW.png: label is 1
# Index: 114
# ori/Train/Negative/GBLG28049L26.png: label is 0
# Index: 115
# ori/Train/Positive/FHPMUU8RYZ98.png: label is 1
# Index: 116
# ori/Train/Positive/665NZRLEILGB.png: label is 1
# Index: 117
# ori/Train/Negative/EWIIGCBGJDWS.png: label is 0
# Index: 118
# ori/Train/Positive/55G70KL5B1VZ.png: label is 1
# Index: 119
# ori/Train/Negative/6X1MD3ANFTHJ.png: label is 0
# Index: 120
# ori/Train/Positive/2POD6Y3852VK.png: label is 1
# Index: 121
# ori/Train/Negative/5H7A1YKUPZ5C.png: label is 0
# Index: 122
# ori/Train/Positive/B53DR3PPV6NL.png: label is 1
# Index: 123
# ori/Train/Negative/8B0D2IPD7HRX.png: label is 0
# Index: 124
# ori/Train/Negative/47QD0AWPPPSD.png: label is 0
# Index: 125
# ori/Train/Negative/EH6XBH3L4UER.png: label is 0
# Index: 126
# ori/Train/Positive/AYNXTVHKFG51.png: label is 1
# Index: 127
# ori/Train/Positive/1FZ8J4YXJDX1.png: label is 1
# Index: 128
# ori/Train/Positive/CQ0MXQZEWACV.png: label is 1
# Index: 129
# ori/Train/Negative/LTCIHNJIX422.png: label is 0
# Index: 130
# ori/Train/Positive/0QH5B76VO4LZ.png: label is 1
# Index: 131
# ori/Train/Negative/IPQRVB64SYKT.png: label is 0
# Index: 132
# ori/Train/Negative/94R0YXVLL982.png: label is 0
# Index: 133
# ori/Train/Negative/G8IHGG17O6LZ.png: label is 0
# Index: 134
# ori/Train/Positive/2WHJUER7NIK3.png: label is 1
# Index: 135
# ori/Train/Negative/I40JALLSMIR3.png: label is 0
# Index: 136
# ori/Train/Positive/1T3GYSHHGH4Q.png: label is 1
# Index: 137
# ori/Train/Positive/4K0PUT21HS44.png: label is 1
# Index: 138
# ori/Train/Positive/FEPVQ81UDMJN.png: label is 1
# Index: 139
# ori/Train/Negative/7O9NNI8F9N0I.png: label is 0
# Index: 140
# ori/Train/Negative/2X8VJ0X7U5NI.png: label is 0
# Index: 141
# ori/Train/Negative/JU2VYLF7PLLW.png: label is 0
# Index: 142
# ori/Train/Negative/K8DWNDKEEO71.png: label is 0
# Index: 143
# ori/Train/Positive/CEB5YB56PEV8.png: label is 1
# Index: 144
# ori/Train/Positive/F78RBE54CB2H.png: label is 1
# Index: 145
# ori/Train/Negative/CSA7JWGBDV1T.png: label is 0
# Index: 146
# ori/Train/Positive/9B3VL90EBS9S.png: label is 1
# Index: 147
# ori/Train/Positive/DBUEMEGADY1J.png: label is 1
# Index: 148
# ori/Train/Negative/BECU5B83PN1C.png: label is 0
# Index: 149
# ori/Train/Positive/6BPQK5DXVU6U.png: label is 1
# Index: 150
# ori/Train/Positive/6OPEU97C8GJZ.png: label is 1
# Index: 151
# ori/Train/Positive/93JE948G30N6.png: label is 1
# Index: 152
# ori/Train/Positive/6QGB5D4ON636.png: label is 1
# Index: 153
# ori/Train/Positive/53AQJPFTK816.png: label is 1
# Index: 154
# ori/Train/Positive/3B9JRVENQT0B.png: label is 1
# Index: 155
# ori/Train/Positive/3L7EK0TL9CRC.png: label is 1
# Index: 156
# ori/Train/Positive/5G84IK9I20W8.png: label is 1
# Index: 157
# ori/Train/Negative/B3DL76MX1ZXB.png: label is 0
# Index: 158
# ori/Train/Positive/6FZ3GU5E4ALM.png: label is 1
# Index: 159
# ori/Train/Positive/8P86Q9ZTCKYT.png: label is 1
# Index: 160
# ori/Train/Negative/50XWEZ3VBGUI.png: label is 0
# Index: 161
# ori/Train/Positive/F34Z6E5ZB7P1.png: label is 1
# Index: 162
# ori/Train/Negative/JPRVUMNNMVFQ.png: label is 0
# Index: 163
# ori/Train/Negative/FJB18FFLK92D.png: label is 0
# Index: 164
# ori/Train/Positive/03NCLGSS0RYH.png: label is 1
# Index: 165
# ori/Train/Positive/18KILRHTS317.png: label is 1
# Index: 166
# ori/Train/Positive/E8VCEELV0PC4.png: label is 1
# Index: 167
# ori/Train/Negative/FZVXFDY4TCXG.png: label is 0
# Index: 168
# ori/Train/Negative/JETPBBZ3UHFB.png: label is 0
# Index: 169
# ori/Train/Positive/0AOO8RY3S7X0.png: label is 1
# Index: 170
# ori/Train/Positive/CC8AH8GHGL55.png: label is 1
# Index: 171
# ori/Train/Negative/3LMYAKYD4OK6.png: label is 0
# Index: 172
# ori/Train/Negative/EE4AJQKU361J.png: label is 0
# Index: 173
# ori/Train/Negative/9DMVV4BQJQSW.png: label is 0
# Index: 174
# ori/Train/Negative/BYN48XR9ZRYS.png: label is 0
# Index: 175
# ori/Train/Positive/32E4Y0B7R5KB.png: label is 1
# Index: 176
# ori/Train/Negative/AIW8OUB9OWJP.png: label is 0
# Index: 177
# ori/Train/Negative/3BNLQC7WVRO8.png: label is 0
# Index: 178
# ori/Train/Positive/A78IE4VZBIBD.png: label is 1
# Index: 179
# ori/Train/Negative/HYG53VN4BET4.png: label is 0
# Index: 180
# ori/Train/Negative/5GMKU21M3P1T.png: label is 0
# Index: 181
# ori/Train/Positive/0M9VRNPRPDPU.png: label is 1
# Index: 182
# ori/Train/Negative/KB58VRHVYT9B.png: label is 0
# Index: 183
# ori/Train/Negative/1749UYWQP9KW.png: label is 0
# Index: 184
# ori/Train/Positive/4YVE0M9C21OC.png: label is 1
# Index: 185
# ori/Train/Negative/2NMWO5CJR3SF.png: label is 0
# Index: 186
# ori/Train/Positive/7A9KYTXZZ8YA.png: label is 1
# Index: 187
# ori/Train/Positive/8MQPZDQRTI6K.png: label is 1
# Index: 188
# ori/Train/Negative/DHSQ5M9RYZ1U.png: label is 0
# Index: 189
# ori/Train/Negative/AOM2357348RL.png: label is 0
# Index: 190
# ori/Train/Negative/DKKEI2H0N41W.png: label is 0
# Index: 191
# ori/Train/Positive/5MYPSHGD5JUW.png: label is 1
# Index: 192
# ori/Train/Negative/6YLRYJIE5BC6.png: label is 0
# Index: 193
# ori/Train/Negative/FBKUZGW2RXNE.png: label is 0
# Index: 194
# ori/Train/Negative/3K5J1TUDYEHL.png: label is 0
# Index: 195
# ori/Train/Negative/H49LOCO5KM3P.png: label is 0
# Index: 196
# ori/Train/Positive/61TUW89X79PJ.png: label is 1
# Index: 197
# ori/Train/Positive/DN6OJ08Q220H.png: label is 1
# Index: 198
# ori/Train/Positive/2PPK2NE1YRJY.png: label is 1
# Index: 199
# ori/Train/Positive/ENJP72W21OHU.png: label is 1
# Index: 200
# ori/Train/Positive/6ZAYZ94NBB26.png: label is 1
# Index: 201
# ori/Train/Negative/C1J0BFGYJGA0.png: label is 0
# Index: 202
# ori/Train/Positive/BABXWTMLZL1S.png: label is 1
# Index: 203
# ori/Train/Positive/8V2KVKME2UWX.png: label is 1
# Index: 204
# ori/Train/Negative/2V42REGZ1NO1.png: label is 0
# Index: 205
# ori/Train/Positive/1KROGG8SYW6R.png: label is 1
# Index: 206
# ori/Train/Negative/KPE5O0XBK2AV.png: label is 0
# Index: 207
# ori/Train/Negative/5KGKR0AC54VG.png: label is 0
# Index: 208
# ori/Train/Positive/BVKQ3DNKM7ZJ.png: label is 1
# Index: 209
# ori/Train/Positive/0QGZGS2IJKND.png: label is 1
# Index: 210
# ori/Train/Positive/5BCLGY1ODF7A.png: label is 1
# Index: 211
# ori/Train/Negative/JLZ5VG2BHCT1.png: label is 0
# Index: 212
# ori/Train/Positive/CSYIF0ZNNLOY.png: label is 1
# Index: 213
# ori/Train/Negative/DCZZMPKZN47W.png: label is 0
# Index: 214
# ori/Train/Negative/GIOJ9N03HTUA.png: label is 0
# Index: 215
# ori/Train/Negative/274FIZ28U0FA.png: label is 0
# Index: 216
# ori/Train/Negative/2747M7PY94Z6.png: label is 0
# Index: 217
# ori/Train/Negative/5M163NLP06AL.png: label is 0
# Index: 218
# ori/Train/Negative/FAGOKY7UIJ3P.png: label is 0
# Index: 219
# ori/Train/Positive/CHY31X1ZTJS7.png: label is 1
# Index: 220
# ori/Train/Negative/7K3ER3CKS5P0.png: label is 0
# Index: 221
# ori/Train/Positive/CY60JM8O2NJF.png: label is 1
# Index: 222
# ori/Train/Positive/60JOUMP7GJ4C.png: label is 1
# Index: 223
# ori/Train/Negative/923N1NKYQBVD.png: label is 0
# Index: 224
# ori/Train/Negative/DJ08IYUNKNQ1.png: label is 0
# Index: 225
# ori/Train/Negative/6NIYT01UH2LN.png: label is 0
# Index: 226
# ori/Train/Negative/76DDOHV8GE26.png: label is 0
# Index: 227
# ori/Train/Positive/3N10UULMBJ4H.png: label is 1
# Index: 228
# ori/Train/Negative/J68VK8ZMFUB5.png: label is 0
# Index: 229
# ori/Train/Negative/2ZXWT5HHK49H.png: label is 0
# Index: 230
# ori/Train/Negative/GVSL2T1DLK4O.png: label is 0
# Index: 231
# ori/Train/Positive/1BW9BWSQAMVN.png: label is 1
# Index: 232
# ori/Train/Negative/FB9Y1ABRH0ER.png: label is 0
# Index: 233
# ori/Train/Positive/2L38EYTNCDKJ.png: label is 1
# Index: 234
# ori/Train/Positive/7SDFNEBV7FVE.png: label is 1
# Index: 235
# ori/Train/Positive/4QXIN1W92OPQ.png: label is 1
# Index: 236
# ori/Train/Negative/5T9YMBTBRE0W.png: label is 0
# Index: 237
# ori/Train/Negative/IAQ4BLGQM5AB.png: label is 0
# Index: 238
# ori/Train/Negative/5TLVS7UVSYI7.png: label is 0
# Index: 239
# ori/Train/Negative/36X8C1GK54I3.png: label is 0
# Index: 240
# ori/Train/Negative/DR21CZMMSEMQ.png: label is 0
# Index: 241
# ori/Train/Positive/6OVAYO8TPWA3.png: label is 1
# Index: 242
# ori/Train/Positive/0V8IKSQ0QN2B.png: label is 1
# Index: 243
# ori/Train/Negative/CX0Y4VWMW2IS.png: label is 0
# Index: 244
# ori/Train/Positive/3O8XJOYSDRWI.png: label is 1
# Index: 245
# ori/Train/Positive/13S340CGD21O.png: label is 1
# Index: 246
# ori/Train/Positive/5TVOASHQF6MS.png: label is 1
# Index: 247
# ori/Train/Negative/2Y9AUKZ5UZ3X.png: label is 0
# Index: 248
# ori/Train/Negative/KHWVFXIMNE3I.png: label is 0
# Index: 249
# ori/Train/Positive/0B0YFBW29N87.png: label is 1
# Index: 250
# ori/Train/Negative/JRM4VTGLWOPV.png: label is 0
# Index: 251
# ori/Train/Positive/0J5181WJT36W.png: label is 1
# Index: 252
# ori/Train/Positive/5N251TGUIW9U.png: label is 1
# Index: 253
# ori/Train/Positive/6LHWXPWSPUEI.png: label is 1
# Index: 254
# ori/Train/Positive/AAZU5SD3MPNQ.png: label is 1
# Index: 255
# ori/Train/Negative/6377LAZNEWSJ.png: label is 0
# Index: 256
# ori/Train/Negative/IRHYJDL9Y9SI.png: label is 0
# Index: 257
# ori/Train/Positive/0LJ5DQI0877E.png: label is 1
# Index: 258
# ori/Train/Negative/83WOJDOWLL0W.png: label is 0
# Index: 259
# ori/Train/Negative/5JYLLPRYLLSW.png: label is 0
# Index: 260
# ori/Train/Negative/E2C9Q4BU1OAN.png: label is 0
# Index: 261
# ori/Train/Positive/3OW75OZPLYGH.png: label is 1
# Index: 262
# ori/Train/Positive/0VXR0CHAIHRO.png: label is 1
# Index: 263
# ori/Train/Positive/2Z5HMQU0OX6U.png: label is 1
# Index: 264
# ori/Train/Positive/AOWY1U5EUD6L.png: label is 1
# Index: 265
# ori/Train/Negative/6QOIC14W64FE.png: label is 0
# Index: 266
# ori/Train/Positive/1DVGZ10AQODT.png: label is 1
# Index: 267
# ori/Train/Negative/I5NLTZIWBLR0.png: label is 0
# Index: 268
# ori/Train/Negative/AGGB8AQCT2F0.png: label is 0
# Index: 269
# ori/Train/Negative/E9ZTGM1JGD8I.png: label is 0
# Index: 270
# ori/Train/Positive/77ZWBC7JCAFT.png: label is 1
# Index: 271
# ori/Train/Negative/CT70V54K57AQ.png: label is 0
# Index: 272
# ori/Train/Negative/3PP68DKD33MW.png: label is 0
# Index: 273
# ori/Train/Negative/A7P7E4SZ3HWH.png: label is 0
# Index: 274
# ori/Train/Negative/4MIL3QULGPCA.png: label is 0
# Index: 275
# ori/Train/Positive/316Q8IUUNHU9.png: label is 1
# Index: 276
# ori/Train/Negative/3JMP0SN4JGMV.png: label is 0
# Index: 277
# ori/Train/Negative/IY2LXGIKO0CQ.png: label is 0
# Index: 278
# ori/Train/Positive/4Z6QBTWN7E53.png: label is 1
# Index: 279
# ori/Train/Positive/6Z7RCQOXPRYL.png: label is 1
# Index: 280
# ori/Train/Positive/0MS2H4VHIR5Y.png: label is 1
# Index: 281
# ori/Train/Negative/ISZZSIZMAVA6.png: label is 0
# Index: 282
# ori/Train/Negative/IKEXKWOKZWK2.png: label is 0
# Index: 283
# ori/Train/Negative/82PXT0W1EQJD.png: label is 0
# Index: 284
# ori/Train/Negative/C5ZTUT6J3NN4.png: label is 0
# Index: 285
# ori/Train/Negative/348XO0OV4LA5.png: label is 0
# Index: 286
# ori/Train/Negative/2P25X7PP3FW1.png: label is 0
# Index: 287
# ori/Train/Positive/3G6K356MXQY6.png: label is 1
# Index: 288
# ori/Train/Negative/HB1QL22YOJ7M.png: label is 0
# Index: 289
# ori/Train/Negative/6QXSXC89YIFJ.png: label is 0
# Index: 290
# ori/Train/Positive/4P2HM8BOC43X.png: label is 1
# Index: 291
# ori/Train/Negative/26ZN5T1BTVWP.png: label is 0
# Index: 292
# ori/Train/Positive/3KQTF0ATEAHO.png: label is 1
# Index: 293
# ori/Train/Negative/JLUY0TISPGW8.png: label is 0
# Index: 294
# ori/Train/Positive/2RHYHIP807U3.png: label is 1
# Index: 295
# ori/Train/Positive/34OBJ6E4UD5Z.png: label is 1
# Index: 296
# ori/Train/Negative/6Z6P07K6SJRC.png: label is 0
# Index: 297
# ori/Train/Positive/BLEM1MGGD1WL.png: label is 1
# Index: 298
# ori/Train/Positive/08SWVHS6KGZX.png: label is 1
# Index: 299
# ori/Train/Positive/DGOHWT7W9HVI.png: label is 1
# Index: 300
# ori/Train/Positive/0335PTP7UUIC.png: label is 1
# Index: 301
# ori/Train/Negative/H2FYQ8V41F2Z.png: label is 0
# Index: 302
# ori/Train/Negative/GIVYMN7R44Y9.png: label is 0
# Index: 303
# ori/Train/Positive/C65WZARF63YK.png: label is 1
# Index: 304
# ori/Train/Negative/6VGXI2H2W3B1.png: label is 0
# Index: 305
# ori/Train/Positive/0TNNS8250XX4.png: label is 1
# Index: 306
# ori/Train/Positive/1F30WKEAKYE0.png: label is 1
# Index: 307
# ori/Train/Negative/KW0NRXF8CB7E.png: label is 0
# Index: 308
# ori/Train/Negative/3C82V0LYRILV.png: label is 0
# Index: 309
# ori/Train/Negative/9JVL1FX6WE31.png: label is 0
# Index: 310
# ori/Train/Negative/ITP14KO8P1KF.png: label is 0
# Index: 311
# ori/Train/Positive/5DIU74KLW5JM.png: label is 1
# Index: 312
# ori/Train/Positive/5XSY2KYHLEHC.png: label is 1
# Index: 313
# ori/Train/Positive/7AZL1NYYLM7A.png: label is 1
# Index: 314
# ori/Train/Negative/GGVQN1VXTLS4.png: label is 0
# Index: 315
# ori/Train/Positive/82NVK0ETAUXY.png: label is 1
# Index: 316
# ori/Train/Positive/CQK7RQAPSZ6A.png: label is 1
# Index: 317
# ori/Train/Positive/6Y7128LA1MH7.png: label is 1
# Index: 318
# ori/Train/Positive/6XTY4LH3IAD3.png: label is 1
# Index: 319
# ori/Train/Negative/GX8BI0QP5IWY.png: label is 0
# Index: 320
# ori/Train/Negative/G91JPT11KX7C.png: label is 0
# Index: 321
# ori/Train/Negative/7CFVLLGET0LO.png: label is 0
# Index: 322
# ori/Train/Negative/K9VEMT132NUU.png: label is 0
# Index: 323
# ori/Train/Negative/12H2PDMB8JE4.png: label is 0
# Index: 324
# ori/Train/Negative/4L6LKKL27HQS.png: label is 0
# Index: 325
# ori/Train/Negative/36JK0102SUK3.png: label is 0
# Index: 326
# ori/Train/Negative/16OB6ARZUUPF.png: label is 0
# Index: 327
# ori/Train/Negative/HBND1GY7RV4Z.png: label is 0
# Index: 328
# ori/Train/Positive/04N36VTFQUC1.png: label is 1
# Index: 329
# ori/Train/Positive/7ERIUJG8LB88.png: label is 1
# Index: 330
# ori/Train/Positive/3O3OVY05HDV7.png: label is 1
# Index: 331
# ori/Train/Negative/4V2AF56UNVJU.png: label is 0
# Index: 332
# ori/Train/Negative/CX571X4WM9JU.png: label is 0
# Index: 333
# ori/Train/Negative/67EJSATZ7ZFI.png: label is 0
# Index: 334
# ori/Train/Negative/63Y5NHDIQDRH.png: label is 0
# Index: 335
# ori/Train/Positive/F3QFDEJ43N7T.png: label is 1
# Index: 336
# ori/Train/Positive/BWKH9KTVQINB.png: label is 1
# Index: 337
# ori/Train/Negative/B65EQ34J55DP.png: label is 0
# Index: 338
# ori/Train/Positive/7HZV132NZDBX.png: label is 1
# Index: 339
# ori/Train/Positive/08N4FMSW78UZ.png: label is 1
# Index: 340
# ori/Train/Negative/IH5LO0XNKWFL.png: label is 0
# Index: 341
# ori/Train/Positive/95DXSE7XJVJ9.png: label is 1
# Index: 342
# ori/Train/Negative/5ICLI4UYXQ6Z.png: label is 0
# Index: 343
# ori/Train/Positive/0TX31BDMYO95.png: label is 1
# Index: 344
# ori/Train/Positive/9MRDYWHLBTGD.png: label is 1
# Index: 345
# ori/Train/Negative/66N4GU6T2CWV.png: label is 0
# Index: 346
# ori/Train/Negative/KKWLFOZBO7CH.png: label is 0
# Index: 347
# ori/Train/Positive/18VZNL0FX3QR.png: label is 1
# Index: 348
# ori/Train/Positive/1G8LKGPT1ZBV.png: label is 1
# Index: 349
# ori/Train/Negative/4SVCELFWNXSO.png: label is 0
# Index: 350
# ori/Train/Positive/3REZUJ5M3QNL.png: label is 1
# Index: 351
# ori/Train/Negative/JHBH4KU2ITC3.png: label is 0
# Index: 352
# ori/Train/Positive/FICBBQ3MF4A7.png: label is 1
# Index: 353
# ori/Train/Negative/361BDH0N7FPW.png: label is 0
# Index: 354
# ori/Train/Positive/4P7OQC44LR3Q.png: label is 1
# Index: 355
# ori/Train/Negative/43BDXNHUQP1X.png: label is 0
# Index: 356
# ori/Train/Negative/68UKA74DI4L7.png: label is 0
# Index: 357
# ori/Train/Negative/IK50L9CCDSOG.png: label is 0
# Index: 358
# ori/Train/Positive/CKSM56KGM687.png: label is 1
# Index: 359
# ori/Train/Negative/G08PQ6Z4LKIC.png: label is 0
# Index: 360
# ori/Train/Positive/536QDPUN5PHU.png: label is 1
# Index: 361
# ori/Train/Positive/CXMUI1CPZ5CM.png: label is 1
# Index: 362
# ori/Train/Positive/5EWUJAWV9B3V.png: label is 1
# Index: 363
# ori/Train/Negative/6TYCCVMAG3QG.png: label is 0
# Index: 364
# ori/Train/Positive/5Z0ET45POZ32.png: label is 1
# Index: 365
# ori/Train/Negative/64IAX6BK8UEP.png: label is 0
# Index: 366
# ori/Train/Positive/BLL6PR2G1XZ5.png: label is 1
# Index: 367
# ori/Train/Negative/HBFSSLXT4YZ0.png: label is 0
# Index: 368
# ori/Train/Negative/IWV9DOAPTS62.png: label is 0
# Index: 369
# ori/Train/Positive/DOEPU3AVLBVI.png: label is 1
# Index: 370
# ori/Train/Negative/A9TY3B1H6OO5.png: label is 0
# Index: 371
# ori/Train/Positive/5W25B61KQGMW.png: label is 1
# Index: 372
# ori/Train/Negative/AV9C79DM7W59.png: label is 0
# Index: 373
# ori/Train/Positive/D2V6ISL6YZE3.png: label is 1
# Index: 374
# ori/Train/Positive/7G5SCM2TX6TQ.png: label is 1
# Index: 375
# ori/Train/Positive/2G4B6I2Y0X42.png: label is 1
# Index: 376
# ori/Train/Negative/ICP9ABE8GRAI.png: label is 0
# Index: 377
# ori/Train/Positive/75WF7499I14L.png: label is 1
# Index: 378
# ori/Train/Positive/4NGWPIES0ZSU.png: label is 1
# Index: 379
# ori/Train/Positive/2IT8DI2ASI9I.png: label is 1
# Index: 380
# ori/Train/Positive/1DSII7KV8TJE.png: label is 1
# Index: 381
# ori/Train/Negative/K3DAYUFN8KQS.png: label is 0
# Index: 382
# ori/Train/Negative/A6SI7YQA286V.png: label is 0
# Index: 383
# ori/Train/Positive/4L52TNXJY88Q.png: label is 1
# Index: 384
# ori/Train/Positive/0D6T1GVZUWI8.png: label is 1
# Index: 385
# ori/Train/Negative/D06JY260WG4L.png: label is 0
# Index: 386
# ori/Train/Positive/07D5XRJ6YSMZ.png: label is 1
# Index: 387
# ori/Train/Negative/BG5VZ7HYKBC8.png: label is 0
# Index: 388
# ori/Train/Positive/AYYHBHQBBY6X.png: label is 1
# Index: 389
# ori/Train/Positive/BII0KZLR1KY4.png: label is 1
# Index: 390
# ori/Train/Positive/BX7QUJSUCCZ8.png: label is 1
# Index: 391
# ori/Train/Positive/170Z5J2AGSQO.png: label is 1
# Index: 392
# ori/Train/Negative/04001LN2G1QX.png: label is 0
# Index: 393
# ori/Train/Positive/24UURCXUMWHA.png: label is 1
# Index: 394
# ori/Train/Positive/711Y6NAG1QYC.png: label is 1
# Index: 395
# ori/Train/Negative/33QV90AMTYWP.png: label is 0
# Index: 396
# ori/Train/Positive/2J8LWPY6B7A2.png: label is 1
# Index: 397
# ori/Train/Negative/44EX48YOOK9K.png: label is 0
# Index: 398
# ori/Train/Negative/07LL2BYSNJR5.png: label is 0
# Index: 399
# ori/Train/Positive/1ZEVUVNMU8RL.png: label is 1
# Index: 400
# ori/Train/Positive/62EAG1W8E2I5.png: label is 1
# Index: 401
# ori/Train/Negative/K9B1Q05XIQJ5.png: label is 0
# Index: 402
# ori/Train/Negative/IB786XGIALB8.png: label is 0
# Index: 403
# ori/Train/Negative/8C2ZSAVH0IK2.png: label is 0
# Index: 404
# ori/Train/Positive/7Y15AW27R28C.png: label is 1
# Index: 405
# ori/Train/Positive/3E0CKM64XOVB.png: label is 1
# Index: 406
# ori/Train/Negative/IDVD2L5JWB72.png: label is 0
# Index: 407
# ori/Train/Positive/6S3EJS6FRJ9Y.png: label is 1
# Index: 408
# ori/Train/Positive/5XU12AHCLQPR.png: label is 1
# Index: 409
# ori/Train/Positive/ACLBFR7U9483.png: label is 1
# Index: 410
# ori/Train/Negative/A561FBWWQOUD.png: label is 0
# Index: 411
# ori/Train/Positive/2CVM7E3AH5A3.png: label is 1
# Index: 412
# ori/Train/Negative/2RLP16V2F1LM.png: label is 0
# Index: 413
# ori/Train/Negative/HEBBGP6DM092.png: label is 0
# Index: 414
# ori/Train/Negative/2U9PPZGO86AO.png: label is 0
# Index: 415
# ori/Train/Positive/4UDB6PBS4AJ3.png: label is 1
# Index: 416
# ori/Train/Positive/BSN75R6RC9ZS.png: label is 1
# Index: 417
# ori/Train/Negative/361T522Z17KP.png: label is 0
# Index: 418
# ori/Train/Negative/32M75U7VCCCN.png: label is 0
# Index: 419
# ori/Train/Positive/5L77L5ZP7VL9.png: label is 1
# Index: 420
# ori/Train/Negative/8ZV6SK51FEGB.png: label is 0
# Index: 421
# ori/Train/Negative/74MM1VQZ9ZTX.png: label is 0
# Index: 422
# ori/Train/Negative/J1L1IM74TGG6.png: label is 0
# Index: 423
# ori/Train/Negative/4552A1U90BU0.png: label is 0
# Index: 424
# ori/Train/Positive/7FGAQDT344V7.png: label is 1
# Index: 425
# ori/Train/Positive/DPROJHQHQNTJ.png: label is 1
# Index: 426
# ori/Train/Negative/JXFKKVT81VJP.png: label is 0
# Index: 427
# ori/Train/Negative/G8JI5PCRUKJC.png: label is 0
# Index: 428
# ori/Train/Positive/0EWH97SL8YY8.png: label is 1
# Index: 429
# ori/Train/Negative/51IA7KGNU7BR.png: label is 0
# Index: 430
# ori/Train/Negative/H1EW7ZRXAFKN.png: label is 0
# Index: 431
# ori/Train/Positive/4VDM2F2GSJVB.png: label is 1
# Index: 432
# ori/Train/Positive/2ZOR144NODUP.png: label is 1
# Index: 433
# ori/Train/Positive/3BGW7FWULXJG.png: label is 1
# Index: 434
# ori/Train/Positive/B48XFR4ZJVOJ.png: label is 1
# Index: 435
# ori/Train/Positive/4D46052S1RJT.png: label is 1
# Index: 436
# ori/Train/Negative/9J658WVCKDGJ.png: label is 0
# Index: 437
# ori/Train/Positive/74XXSLB33ZGX.png: label is 1
# Index: 438
# ori/Train/Positive/BI42TJ87KKYS.png: label is 1
# Index: 439
# ori/Train/Positive/1GRC0T4VDJG8.png: label is 1
# Index: 440
# ori/Train/Positive/0XILPOOJBCSL.png: label is 1
# Index: 441
# ori/Train/Positive/E1HFJILM7G1C.png: label is 1
# Index: 442
# ori/Train/Negative/JIP4R1D3AO1W.png: label is 0
# Index: 443
# ori/Train/Negative/ETCK585CRLC0.png: label is 0
# Index: 444
# ori/Train/Positive/DNLR288MVEDM.png: label is 1
# Index: 445
# ori/Train/Negative/FAPYF8Z8C6I5.png: label is 0
# Index: 446
# ori/Train/Positive/0NC27JBIYJTJ.png: label is 1
# Index: 447
# ori/Train/Positive/7EBVE9CIEME2.png: label is 1
# Index: 448
# ori/Train/Negative/LQ0HNIB2WG9I.png: label is 0
# Index: 449
# ori/Train/Negative/DHS4YPD57RFD.png: label is 0
# Index: 450
# ori/Train/Negative/269YO8R6BVNV.png: label is 0
# Index: 451
# ori/Train/Positive/5PDUY4MT0W2B.png: label is 1
# Index: 452
# ori/Train/Negative/39RQUY5FVF7R.png: label is 0
# Index: 453
# ori/Train/Positive/A1I0ZZ6DRB70.png: label is 1
# Index: 454
# ori/Train/Positive/DX302KH6A14G.png: label is 1
# Index: 455
# ori/Train/Negative/DNNORZ902ZIU.png: label is 0
# Index: 456
# ori/Train/Positive/3K4BHA90XQZY.png: label is 1
# Index: 457
# ori/Train/Positive/EQ42MKDW9HQL.png: label is 1
# Index: 458
# ori/Train/Negative/J52KBJ4G39AK.png: label is 0
# Index: 459
# ori/Train/Positive/8RV87XRIUDE1.png: label is 1
# Index: 460
# ori/Train/Negative/GXD5CR9SD9XR.png: label is 0
# Index: 461
# ori/Train/Positive/1IQKDMHWZ78P.png: label is 1
# Index: 462
# ori/Train/Negative/C9AMCGYXV1TB.png: label is 0
# Index: 463
# ori/Train/Negative/3MMSOXLPZU84.png: label is 0
# Index: 464
# ori/Train/Negative/IADX6Q7KU3CH.png: label is 0
# Index: 465
# ori/Train/Negative/CQUJXY4343FQ.png: label is 0
# Index: 466
# ori/Train/Positive/2KEN0U4ER3TT.png: label is 1
# Index: 467
# ori/Train/Negative/31NV5AKLGH69.png: label is 0
# Index: 468
# ori/Train/Positive/1JPMNRVXGVCT.png: label is 1
# Index: 469
# ori/Train/Positive/3TXFIN4TFD9U.png: label is 1
# Index: 470
# ori/Train/Positive/BBUJL674O91U.png: label is 1
# Index: 471
# ori/Train/Positive/5T2EM4RR5SVC.png: label is 1
# Index: 472
# ori/Train/Positive/68VJ8R0FRKPO.png: label is 1
# Index: 473
# ori/Train/Negative/3EFCXFKNK9FS.png: label is 0
# Index: 474
# ori/Train/Positive/34I2545IN0PG.png: label is 1
# Index: 475
# ori/Train/Negative/5Y4XQAOGO7B5.png: label is 0
# Index: 476
# ori/Train/Negative/A01USC4OZ9VT.png: label is 0
# Index: 477
# ori/Train/Negative/IYGEG8570S0R.png: label is 0
# Index: 478
# ori/Train/Positive/5S4SLL4KN4UW.png: label is 1
# Index: 479
# ori/Train/Negative/D53M8RR0ZJNT.png: label is 0
# Index: 480
# ori/Train/Positive/0JWAP0Z8NFYM.png: label is 1
# Index: 481
# ori/Train/Negative/99B1ZLFC3AZ5.png: label is 0
# Index: 482
# ori/Train/Negative/HX64A4288KHB.png: label is 0
# Index: 483
# ori/Train/Positive/D4VI13WRZFA4.png: label is 1
# Index: 484
# ori/Train/Negative/76AGH8GKBX2L.png: label is 0
# Index: 485
# ori/Train/Negative/8YW355VKGUDA.png: label is 0
# Index: 486
# ori/Train/Negative/61U8VDW4C67E.png: label is 0
# Index: 487
# ori/Train/Negative/6UVAWT1HWWXW.png: label is 0
# Index: 488
# ori/Train/Positive/9P3SHGF2QD3W.png: label is 1
# Index: 489
# ori/Train/Negative/HNFWEFYK47QM.png: label is 0
# Index: 490
# ori/Train/Negative/DJ6VDP6ESGR2.png: label is 0
# Index: 491
# ori/Train/Positive/AZ5W3C9YN33T.png: label is 1
# Index: 492
# ori/Train/Positive/27CJMG96UYR2.png: label is 1
# Index: 493
# ori/Train/Negative/KBEB54VHKEC8.png: label is 0
# Index: 494
# ori/Train/Negative/IHU388AH2GFG.png: label is 0
# Index: 495
# ori/Train/Negative/3DOP0PTX4GUL.png: label is 0
# Index: 496
# ori/Train/Positive/CKNM4FJEJX7E.png: label is 1
# Index: 497
# ori/Train/Negative/7SOTTXBBE9QO.png: label is 0
# Index: 498
# ori/Train/Positive/CZCJZISXI6AP.png: label is 1
# Index: 499
# ori/Train/Negative/JMSG3D29IUKM.png: label is 0
# Index: 500
# ori/Train/Positive/7EU9N3DBQA18.png: label is 1
# Index: 501
# ori/Train/Negative/41QUDSWZZPEH.png: label is 0
# Index: 502
# ori/Train/Positive/4YQC8OAOKFUV.png: label is 1
# Index: 503
# ori/Train/Negative/HFWRG6FFFLDF.png: label is 0
# Index: 504
# ori/Train/Negative/8CLR7UC42F1A.png: label is 0
# Index: 505
# ori/Train/Positive/4E707BV7GAGJ.png: label is 1
# Index: 506
# ori/Train/Negative/4WG7UK0RJV91.png: label is 0
# Index: 507
# ori/Train/Positive/CJJF6A7W3KNJ.png: label is 1
# Index: 508
# ori/Train/Positive/77CBCT41OABX.png: label is 1
# Index: 509
# ori/Train/Negative/4UNFJTUPVJCT.png: label is 0
# Index: 510
# ori/Train/Negative/76HESOPE8EB1.png: label is 0
# Index: 511
# ori/Train/Positive/55K1XKWSKR7J.png: label is 1
# Index: 512
# ori/Train/Positive/0RMAFHAL04E3.png: label is 1
# Index: 513
# ori/Train/Positive/BQVO244GQH6Q.png: label is 1
# Index: 514
# ori/Train/Negative/9J56XA132UUH.png: label is 0
# Index: 515
# ori/Train/Negative/6OIZI62V4J1W.png: label is 0
# Index: 516
# ori/Train/Positive/53WDBJ3WB24C.png: label is 1
# Index: 517
# ori/Train/Positive/CT73B4D63REQ.png: label is 1
# Index: 518
# ori/Train/Negative/FOUPPL70KQTP.png: label is 0
# Index: 519
# ori/Train/Negative/LX5ZPCUE52PX.png: label is 0
# Index: 520
# ori/Train/Positive/1MGLDNJBF6YH.png: label is 1
# Index: 521
# ori/Train/Negative/H3ICIM9R2SQN.png: label is 0
# Index: 522
# ori/Train/Positive/60HWHL10I7XW.png: label is 1
# Index: 523
# ori/Train/Negative/4MH0PVQQ711I.png: label is 0
# Index: 524
# ori/Train/Positive/CX9U735XMKHQ.png: label is 1
# Index: 525
# ori/Train/Negative/043L6YSHS37V.png: label is 0
# Index: 526
# ori/Validation/Positive/8LFNLMC50RBN.png: label is 1
# Index: 1
# ori/Validation/Negative/IQU04CXE1RH6.png: label is 0
# Index: 2
# ori/Validation/Positive/7YXRVS4891CT.png: label is 1
# Index: 3
# ori/Validation/Negative/8CN70CPT21CM.png: label is 0
# Index: 4
# ori/Validation/Positive/3TLO2FHPQCJ6.png: label is 1
# Index: 5
# ori/Validation/Negative/3UXGJHXFYUJ6.png: label is 0
# Index: 6
# ori/Validation/Positive/3S8ISJI19IYM.png: label is 1
# Index: 7
# ori/Validation/Negative/EEZ2FIDMLC5E.png: label is 0
# Index: 8
# ori/Validation/Positive/73SHVACPO9JE.png: label is 1
# Index: 9
# ori/Validation/Positive/88I17KUCF93F.png: label is 1
# Index: 10
# ori/Validation/Positive/2RSTH9YW823U.png: label is 1
# Index: 11
# ori/Validation/Positive/BQDPZI5SFBJQ.png: label is 1
# Index: 12
# ori/Validation/Positive/9HYWZ44HUGDU.png: label is 1
# Index: 13
# ori/Validation/Negative/248M8Q0589QE.png: label is 0
# Index: 14
# ori/Validation/Negative/C5XMFXA0RQGW.png: label is 0
# Index: 15
# ori/Validation/Negative/3I18D6G7L2SG.png: label is 0
# Index: 16
# ori/Validation/Negative/7YYB531Z0TB9.png: label is 0
# Index: 17
# ori/Validation/Negative/EVKU1PXCMSXF.png: label is 0
# Index: 18
# ori/Validation/Negative/LUG0MPJK89XW.png: label is 0
# Index: 19
# ori/Validation/Positive/33A3SHPNWRI5.png: label is 1
# Index: 20
# ori/Validation/Negative/JQI0MAX8LHQ4.png: label is 0
# Index: 21
# ori/Validation/Negative/FGT3XGMYJYCB.png: label is 0
# Index: 22
# ori/Validation/Positive/6ET14HU257AM.png: label is 1
# Index: 23
# ori/Validation/Negative/4FAYEMVW8U3E.png: label is 0
# Index: 24
# ori/Validation/Negative/5FE7A43FBLTK.png: label is 0
# Index: 25
# ori/Validation/Positive/BHJRFVZJV2DK.png: label is 1
# Index: 26
# ori/Validation/Negative/4BULQPMOVNOK.png: label is 0
# Index: 27
# ori/Validation/Positive/38JZV9OX2FEU.png: label is 1
# Index: 28
# ori/Validation/Negative/3G3P3BKUREQG.png: label is 0
# Index: 29
# ori/Validation/Negative/25II7MBEQ8F8.png: label is 0
# Index: 30
# ori/Validation/Positive/8ODLOVXLBMHD.png: label is 1
# Index: 31
# ori/Validation/Negative/9W1BML02TW8F.png: label is 0
# Index: 32
# ori/Validation/Positive/6VK52P0IEBTH.png: label is 1
# Index: 33
# ori/Validation/Negative/EUO28M8QGBZK.png: label is 0
# Index: 34
# ori/Validation/Positive/3GTLZR9OB0TM.png: label is 1
# Index: 35
# ori/Validation/Negative/3NUOK47U8A23.png: label is 0
# Index: 36
# ori/Validation/Negative/444WLBTR9P9Q.png: label is 0
# Index: 37
# ori/Validation/Positive/2NISKP82M36P.png: label is 1
# Index: 38
# ori/Validation/Negative/ISMPNSS1JB4P.png: label is 0
# Index: 39
# ori/Validation/Positive/3NDTNAT0654N.png: label is 1
# Index: 40
# ori/Validation/Positive/1Z3ZPJ9H7FK3.png: label is 1
# Index: 41
# ori/Validation/Positive/BDJPXQUL7CXC.png: label is 1
# Index: 42
# ori/Validation/Negative/8BT8MXBJ1IXV.png: label is 0
# Index: 43
# ori/Validation/Positive/1GA9G81QGXVW.png: label is 1
# Index: 44
# ori/Validation/Negative/4M07UA6FWJ2N.png: label is 0
# Index: 45
# ori/Validation/Negative/LVNL0U60KDOQ.png: label is 0
# Index: 46
# ori/Validation/Positive/E5BNO0F3B1EW.png: label is 1
# Index: 47
# ori/Validation/Negative/5SKBCT8418FC.png: label is 0
# Index: 48
# ori/Validation/Positive/FB1FP8SS8U5I.png: label is 1
# Index: 49
# ori/Validation/Positive/9JTH9HDTRDEZ.png: label is 1
# Index: 50
# ori/Validation/Positive/2H371EIQCKJB.png: label is 1
# Index: 51
# ori/Validation/Positive/BHEMQKTKQ63F.png: label is 1
# Index: 52
# ori/Validation/Negative/90O3WBPDT6DT.png: label is 0
# Index: 53
# ori/Validation/Positive/BRDZA2TH6A2Z.png: label is 1
# Index: 54
# ori/Validation/Negative/310I2S4G5FT7.png: label is 0
# Index: 55
# ori/Validation/Positive/189S7TJ5JS1Q.png: label is 1
# Index: 56
# ori/Validation/Negative/HK98QFJY0SSY.png: label is 0
# Index: 57
# ori/Validation/Negative/69LL3JJ8MJ7R.png: label is 0
# Index: 58
# ori/Validation/Negative/5DPCE8O3U63X.png: label is 0
# Index: 59
# ori/Validation/Positive/7L6SP4ZCHP5G.png: label is 1
# Index: 60
# ori/Validation/Positive/BNDN0T2596OP.png: label is 1
# Index: 61
# ori/Validation/Negative/3J0WPJLJSJW5.png: label is 0
# Index: 62
# ori/Validation/Negative/2WDF4KX9P39S.png: label is 0
# Index: 63
# ori/Validation/Negative/C7S33XM7WD9M.png: label is 0
# Index: 64
# ori/Validation/Negative/HJ0VSBMNN1H2.png: label is 0
# Index: 65
# ori/Validation/Negative/5O4NQRKGQOEW.png: label is 0
# Index: 66
# ori/Validation/Positive/084FLGPATOWI.png: label is 1
# Index: 67
# ori/Validation/Negative/001751D6P8MB.png: label is 0
# Index: 68
# ori/Validation/Negative/7PYJQPALZKR6.png: label is 0
# Index: 69
# ori/Validation/Negative/7V9NSH2CRYLT.png: label is 0
# Index: 70
# ori/Validation/Positive/BEYFFXLYE1U1.png: label is 1
# Index: 71
# ori/Validation/Positive/5VDM1WCFG4JI.png: label is 1
# Index: 72
# ori/Validation/Positive/3DRWTZIHBP6W.png: label is 1
# Index: 73
# ori/Validation/Positive/4D8B3Q7ZFOL8.png: label is 1
# Index: 74
# ori/Validation/Positive/2WN7CBBVFPMG.png: label is 1
# Index: 75
# ori/Validation/Negative/5QU0T53O9K3R.png: label is 0
# Index: 76
# ori/Validation/Negative/53QMUEZIU2X0.png: label is 0
# Index: 77
# ori/Validation/Positive/5DUMJPRO6DW3.png: label is 1
# Index: 78
# ori/Validation/Positive/BXGFQ276OD6X.png: label is 1
# Index: 79
# ori/Validation/Negative/32KPFA1B9ABY.png: label is 0
# Index: 80
# ori/Validation/Negative/81W9MZ3Z5III.png: label is 0
# Index: 81
# ori/Validation/Positive/BB6C3389HM8Y.png: label is 1
# Index: 82
# ori/Validation/Positive/1KNSOV6IIJ3Y.png: label is 1
# Index: 83
# ori/Validation/Negative/EBU5KRZECWXW.png: label is 0
# Index: 84
# ori/Validation/Negative/6PKSRHGC3I1S.png: label is 0
# Index: 85
# ori/Validation/Negative/CGGMJWZCJ59J.png: label is 0
# Index: 86
# ori/Validation/Positive/4P6LTPOFX9F4.png: label is 1
# Index: 87
# ori/Validation/Negative/8QFE29KBZFNY.png: label is 0
# Index: 88
# ori/Validation/Positive/2S2YOBI2POP5.png: label is 1
# Index: 89
# ori/Validation/Negative/HHPP6S2MFJU7.png: label is 0
# Index: 90
# ori/Validation/Positive/59QFI0M8F8JO.png: label is 1
# Index: 91
# ori/Validation/Positive/69G2IMVLDCDV.png: label is 1
# Index: 92
# ori/Validation/Positive/DZUXBO96FZG9.png: label is 1
# Index: 93
# ori/Validation/Negative/H4902FJZDNLE.png: label is 0
# Index: 94
# ori/Validation/Positive/4TR8LBC1TNHD.png: label is 1
# Index: 95
# ori/Validation/Negative/JATNTXKHZCQ5.png: label is 0
# Index: 96
# ori/Validation/Negative/I9QYQ62YWU5B.png: label is 0
# Index: 97
# ori/Validation/Negative/AZJN6Y65RGJ0.png: label is 0
# Index: 98
# ori/Validation/Positive/5G55HRHP6D3R.png: label is 1
# Index: 99
# ori/Validation/Positive/BUR5L2RMKK9S.png: label is 1
# Index: 100
# ori/Validation/Positive/7ASD9L2XMQRR.png: label is 1
# Index: 101
# ori/Validation/Positive/0S85R53UM5KV.png: label is 1
# Index: 102
# ori/Validation/Positive/3RW6A0FITSMQ.png: label is 1
# Index: 103
# ori/Validation/Positive/6LP2ZT26W9XB.png: label is 1
# Index: 104
# ori/Validation/Negative/3UOAXEXPXGFT.png: label is 0
# Index: 105
# ori/Validation/Negative/EE3957DJ4E3E.png: label is 0
# Index: 106
# ori/Validation/Positive/72A08UMZHKI1.png: label is 1
# Index: 107
# ori/Validation/Positive/0CWOZDF6X70N.png: label is 1
# Index: 108
# ori/Validation/Positive/2R735ZP1W8YU.png: label is 1
# Index: 109
# ori/Validation/Positive/7MZB6JHGYVCX.png: label is 1
# Index: 110
# ori/Validation/Negative/AFT2W4PEMB5X.png: label is 0
# Index: 111
# ori/Validation/Negative/J6CY2TSG6HQ8.png: label is 0
# Index: 112
# ori/Validation/Positive/8AY6VHENVOPL.png: label is 1
# Index: 113
# ori/Validation/Negative/80T3SAFPDCOY.png: label is 0
# Index: 114
# ori/Validation/Negative/415UWFOBM820.png: label is 0
# Index: 115
# ori/Validation/Negative/IOSXA0GTYMWT.png: label is 0
# Index: 116
# ori/Validation/Positive/9CZIYS6VI2WQ.png: label is 1
# Index: 117
# ori/Validation/Positive/3MVMRD0QI8VJ.png: label is 1
# Index: 118
# ori/Validation/Negative/DJWORQPMDFTU.png: label is 0
# Index: 119
# ori/Validation/Negative/4VLQ1L7OX6AM.png: label is 0
# Index: 120
# ori/Validation/Positive/58PJWWQ79FXV.png: label is 1
# Index: 121
# ori/Validation/Negative/FC425LMNRWP0.png: label is 0
# Index: 122
# ori/Validation/Positive/12UHD0KVWV4O.png: label is 1
# Index: 123
# ori/Validation/Negative/IAK9FUI482P4.png: label is 0
# Index: 124
# ori/Validation/Positive/75FC2M8I3JUD.png: label is 1
# Index: 125
# ori/Validation/Positive/02WZ0DL9JCLU.png: label is 1
# Index: 126
# ori/Validation/Negative/CZK5NDTB2I0Q.png: label is 0
# Index: 127
# ori/Validation/Negative/I6ZFSDW0QSP9.png: label is 0
# Index: 128
# ori/Validation/Negative/60RLH2NC6UU4.png: label is 0
# Index: 129
# ori/Validation/Negative/FW6ZMLIO22Z6.png: label is 0
# Index: 130
# ori/Validation/Positive/8VVKKXQ58RYA.png: label is 1
# Index: 131
# ori/Validation/Positive/36AF3NSVJDFT.png: label is 1
# Index: 132
# ori/Test/Positive/8Z0SPGI45V4L.png: label is 1
# Index: 1
# ori/Test/Negative/ADNLSD8SNW28.png: label is 0
# Index: 2
# ori/Test/Positive/68YEL7Q7LASF.png: label is 1
# Index: 3
# ori/Test/Positive/5WAYXH9JKKCK.png: label is 1
# Index: 4
# ori/Test/Positive/8I8JOSFMVOG5.png: label is 1
# Index: 5
# ori/Test/Negative/6RUHIGX494ZD.png: label is 0
# Index: 6
# ori/Test/Positive/235XNS2JPZG7.png: label is 1
# Index: 7
# ori/Test/Positive/04CLRMPQUK3W.png: label is 1
# Index: 8
# ori/Test/Negative/739FEAD25A59.png: label is 0
# Index: 9
# ori/Test/Negative/FXMSAT49HL4Z.png: label is 0
# Index: 10
# ori/Test/Positive/0HT20178DNJ1.png: label is 1
# Index: 11
# ori/Test/Positive/ABYXSDFZMXQJ.png: label is 1
# Index: 12
# ori/Test/Positive/BKBUTCSJOWNM.png: label is 1
# Index: 13
# ori/Test/Negative/G1M4086MPT8Z.png: label is 0
# Index: 14
# ori/Test/Negative/5XNB9XB6RSGI.png: label is 0
# Index: 15
# ori/Test/Negative/IT2ZDO9XM8TV.png: label is 0
# Index: 16
# ori/Test/Negative/5C0OCAJM5GV1.png: label is 0
# Index: 17
# ori/Test/Positive/3ANLKTTWHEQS.png: label is 1
# Index: 18
# ori/Test/Positive/F4Z03GD5BSD1.png: label is 1
# Index: 19
# ori/Test/Negative/I91IV0I7CJT7.png: label is 0
# Index: 20
# ori/Test/Positive/9GJPFZ2KXODP.png: label is 1
# Index: 21
# ori/Test/Negative/2OD9AHKQ40FB.png: label is 0
# Index: 22
# ori/Test/Positive/BD4TIUW9LGNH.png: label is 1
# Index: 23
# ori/Test/Negative/I21Z4CAYUGM8.png: label is 0
# Index: 24
# ori/Test/Negative/EEX0FGNM65OJ.png: label is 0
# Index: 25
# ori/Test/Negative/2S33HY7QPT2C.png: label is 0
# Index: 26
# ori/Test/Negative/03TRLTSOQUUX.png: label is 0
# Index: 27
# ori/Test/Positive/EMU7MRIN49H7.png: label is 1
# Index: 28
# ori/Test/Positive/0DHUJUCRP1CE.png: label is 1
# Index: 29
# ori/Test/Negative/5ZZQOHEZIOHM.png: label is 0
# Index: 30
# ori/Test/Positive/C5SNSIN56V7B.png: label is 1
# Index: 31
# ori/Test/Positive/AW5F9KWDJYVU.png: label is 1
# Index: 32
# ori/Test/Positive/71AAGH1W9I0H.png: label is 1
# Index: 33
# ori/Test/Positive/85HBYNXLCP5K.png: label is 1
# Index: 34
# ori/Test/Negative/9FW2O3QNSEKL.png: label is 0
# Index: 35
# ori/Test/Negative/7UUBMX31V2ME.png: label is 0
# Index: 36
# ori/Test/Negative/7VFUETE1QNLN.png: label is 0
# Index: 37
# ori/Test/Positive/0M89AXEFEJBC.png: label is 1
# Index: 38
# ori/Test/Negative/CKEKYC8N4RGV.png: label is 0
# Index: 39
# ori/Test/Negative/F0X2Y6PHP6VM.png: label is 0
# Index: 40
# ori/Test/Negative/7E7VZ39O5OWL.png: label is 0
# Index: 41
# ori/Test/Negative/J2E4QZQF22R9.png: label is 0
# Index: 42
# ori/Test/Negative/48PUEML9G4YU.png: label is 0
# Index: 43
# ori/Test/Positive/DIUZ6O0XUE0Q.png: label is 1
# Index: 44
# ori/Test/Positive/CNHT52A6141D.png: label is 1
# Index: 45
# ori/Test/Negative/5A5K0E18GN29.png: label is 0
# Index: 46
# ori/Test/Positive/6WQMGLNV58AI.png: label is 1
# Index: 47
# ori/Test/Positive/1GC968V8HZLI.png: label is 1
# Index: 48
# ori/Test/Positive/3A03CQSMNLT6.png: label is 1
# Index: 49
# ori/Test/Negative/D4BRNWH347FC.png: label is 0
# Index: 50
# ori/Test/Negative/974U29LAN8NE.png: label is 0
# Index: 51
# ori/Test/Negative/IZ1CGTYSC7HK.png: label is 0
# Index: 52
# ori/Test/Positive/02BRSCFKVFLP.png: label is 1
# Index: 53
# ori/Test/Negative/JNZOPYVUN46B.png: label is 0
# Index: 54
# ori/Test/Positive/9H7J8DZ76A0F.png: label is 1
# Index: 55
# ori/Test/Positive/EKIB2VFSZ9UQ.png: label is 1
# Index: 56
# ori/Test/Positive/CGXSMD78GC1Q.png: label is 1
# Index: 57
# ori/Test/Negative/60J2YJU1V3FG.png: label is 0
# Index: 58
# ori/Test/Negative/LJS1FMSFUVV3.png: label is 0
# Index: 59
# ori/Test/Negative/JWQ91WZUSKFF.png: label is 0
# Index: 60
# ori/Test/Positive/7XN3XKAH9PM3.png: label is 1
# Index: 61
# ori/Test/Positive/0WTL4D1ARPAX.png: label is 1
# Index: 62
# ori/Test/Negative/JSPOSBMQBI0M.png: label is 0
# Index: 63
# ori/Test/Negative/JAX66VOAF0C4.png: label is 0
# Index: 64
# ori/Test/Positive/9KU6HBOO9O7V.png: label is 1
# Index: 65
# ori/Test/Positive/CMISE73KYQAB.png: label is 1
# Index: 66
# ori/Test/Positive/5KK1UR31NOLP.png: label is 1
# Index: 67
# ori/Test/Positive/F9NYYPJ3R2TY.png: label is 1
# Index: 68
# ori/Test/Negative/HGE72UYNH9EW.png: label is 0
# Index: 69
# ori/Test/Negative/BZK1NXWH3D83.png: label is 0
# Index: 70
# ori/Test/Positive/31HDHU99KC8V.png: label is 1
# Index: 71
# ori/Test/Negative/6B52AGZRY02M.png: label is 0
# Index: 72
# ori/Test/Negative/GWJWJZC6WRMR.png: label is 0
# Index: 73
# ori/Test/Positive/A870Q5UYNQHE.png: label is 1
# Index: 74
# ori/Test/Positive/7ZAL1LN85FHO.png: label is 1
# Index: 75
# ori/Test/Negative/7MYYYACL06PC.png: label is 0
# Index: 76
# ori/Test/Positive/6ZH6K3U0RDPH.png: label is 1
# Index: 77
# ori/Test/Negative/EYTTJMCU7KWP.png: label is 0
# Index: 78
# ori/Test/Positive/BOQUQVFPQ0Z4.png: label is 1
# Index: 79
# ori/Test/Negative/9MOJ7COXG331.png: label is 0
# Index: 80
# ori/Test/Positive/4VID61KUCAB6.png: label is 1
# Index: 81
# ori/Test/Negative/31OSW6R8TVMX.png: label is 0
# Index: 82
# ori/Test/Positive/5MHUPOZ7N6U6.png: label is 1
# Index: 83
# ori/Test/Negative/2UNGDRHGOY9D.png: label is 0
# Index: 84
# ori/Test/Positive/8N117M9W2T9K.png: label is 1
# Index: 85
# ori/Test/Negative/BAJG536O9Z7C.png: label is 0
# Index: 86
# ori/Test/Negative/7RF0MLAE8EYE.png: label is 0
# Index: 87
# ori/Test/Negative/92E0F4AVTG0R.png: label is 0
# Index: 88
# ori/Test/Positive/5PXQO8Z8BZI5.png: label is 1
# Index: 89
# ori/Test/Negative/J02IQMCUV3JR.png: label is 0
# Index: 90
# ori/Test/Negative/781L4CFNTMDB.png: label is 0
# Index: 91
# ori/Test/Negative/71PWF36YQA05.png: label is 0
# Index: 92
# ori/Test/Positive/4Q3SL87SUUO1.png: label is 1
# Index: 93
# ori/Test/Positive/1DFSUIRRFKNW.png: label is 1
# Index: 94
# ori/Test/Negative/IPY2BPSMRVCL.png: label is 0
# Index: 95
# ori/Test/Negative/904XHAWIXCZE.png: label is 0
# Index: 96
# ori/Test/Positive/9S9RTLA42USI.png: label is 1
# Index: 97
# ori/Test/Positive/6E4Y5MK7QD20.png: label is 1
# Index: 98
# ori/Test/Negative/3LUO67QAWVTY.png: label is 0
# Index: 99
# ori/Test/Negative/BUAW2XI47I2L.png: label is 0
# Index: 100
# ori/Test/Positive/7D6OH63F4N1H.png: label is 1
# Index: 101
# ori/Test/Positive/7JS4R9OUXDBV.png: label is 1
# Index: 102
# ori/Test/Positive/EHE88B224NWM.png: label is 1
# Index: 103
# ori/Test/Negative/730ND716ZANV.png: label is 0
# Index: 104
# ori/Test/Positive/9ZB51RPHJ6OM.png: label is 1
# Index: 105
# ori/Test/Positive/371QARVQ1AC5.png: label is 1
# Index: 106
# ori/Test/Negative/63NKX09OAHEQ.png: label is 0
# Index: 107
# ori/Test/Positive/DR6Y2SKRKRXX.png: label is 1
# Index: 108
# ori/Test/Negative/2YWMRHWW36JU.png: label is 0
# Index: 109
# ori/Test/Positive/3EHDNKMS4NAV.png: label is 1
# Index: 110
# ori/Test/Positive/0I8K6DIDEQYP.png: label is 1
# Index: 111
# ori/Test/Negative/J4L32ND7IW2Z.png: label is 0
# Index: 112
# ori/Test/Negative/FEOG6BGOVJ93.png: label is 0
# Index: 113
# ori/Test/Negative/EC96OXXY7CK4.png: label is 0
# Index: 114
# ori/Test/Positive/2QBS20DJY88G.png: label is 1
# Index: 115
# ori/Test/Negative/AIMSX8OC0H7S.png: label is 0
# Index: 116
# ori/Test/Negative/318NMXTUXP11.png: label is 0
# Index: 117
# ori/Test/Positive/058KHGDH57W5.png: label is 1
# Index: 118
# ori/Test/Positive/0Q3B2C0AGGG0.png: label is 1
# Index: 119
# ori/Test/Positive/4I6SOPDAFXYR.png: label is 1
# Index: 120
# ori/Test/Negative/HKJU8BREZ6V2.png: label is 0
# Index: 121
# ori/Test/Negative/08JL6UZ1L75N.png: label is 0
# Index: 122
# ori/Test/Negative/AXO7MLGYIN0Q.png: label is 0
# Index: 123
# ori/Test/Negative/3KCJNWDW3BU8.png: label is 0
# Index: 124
# ori/Test/Negative/4FQO01HM746M.png: label is 0
# Index: 125
# ori/Test/Negative/77DXISNA2HNW.png: label is 0
# Index: 126
# ori/Test/Negative/66X6QU2WVV1A.png: label is 0
# Index: 127
# ori/Test/Negative/5HQW834KJKLV.png: label is 0
# Index: 128
# ori/Test/Negative/3B2JNE0DXJQG.png: label is 0
# Index: 129
# ori/Test/Positive/CTKBGC736KW8.png: label is 1
# Index: 130
# ori/Test/Positive/4JHUZS30ZAY7.png: label is 1
# Index: 131
# ori/Test/Positive/2UH743293937.png: label is 1
# Index: 132
# ori/Test/Positive/BHKQCSO7B846.png: label is 1
# Index: 133
# ori/Test/Positive/1C5O1EEDIHSK.png: label is 1
# Index: 134
# ori/Test/Negative/9B6FTSSQC75R.png: label is 0
# Index: 135
# ori/Test/Positive/F53CAYSYF2HP.png: label is 1
# Index: 136
# ori/Test/Negative/13F2NVLULMD0.png: label is 0
# Index: 137
# ori/Test/Positive/5GV9YPDVU108.png: label is 1
# Index: 138
# ori/Test/Negative/8ATMMCNG6UIY.png: label is 0
# Index: 139
# ori/Test/Positive/BFWWO4T944JS.png: label is 1
# Index: 140
# ori/Test/Negative/8SG9FQ4C3QU4.png: label is 0
# Index: 141
# ori/Test/Negative/3X1SSGSCCK7N.png: label is 0
# Index: 142
# ori/Test/Positive/DJTIK2M6BWU6.png: label is 1
# Index: 143
# ori/Test/Positive/6UMOT2WT8QWO.png: label is 1
# Index: 144
# ori/Test/Positive/4ERPAFUCLCXX.png: label is 1
# Index: 145
# ori/Test/Negative/FDYAQKMK40UB.png: label is 0
# Index: 146
# ori/Test/Positive/3G47D4SCQPKG.png: label is 1
# Index: 147
# ori/Test/Positive/1WO88X1XDIZE.png: label is 1
# Index: 148
# ori/Test/Negative/JQ5GLD8XV9JQ.png: label is 0
# Index: 149
# ori/Test/Negative/JXVYFALN5X61.png: label is 0
# Index: 150
# ori/Test/Negative/FP06N0T2GMSR.png: label is 0
# Index: 151
# ori/Test/Negative/5L0AMRN9ATC4.png: label is 0
# Index: 152
# ori/Test/Negative/HQIQZJ8X0H10.png: label is 0
# Index: 153
# ori/Test/Positive/7PAVZ2S8URP4.png: label is 1
# Index: 154
# ori/Test/Negative/JWFI86GO9URS.png: label is 0
# Index: 155
# ori/Test/Positive/DSIV4Q9VWCMG.png: label is 1
# Index: 156
# ori/Test/Positive/5LIS8WA8DSM5.png: label is 1
# Index: 157
# ori/Test/Negative/6M4T4A0MKSWE.png: label is 0
# Index: 158
# ori/Test/Negative/G1CHVEEYIF4X.png: label is 0
# Index: 159
# ori/Test/Positive/3BQAMPEFF27C.png: label is 1
# Index: 160
# ori/Test/Positive/4PWOCW2NIXB1.png: label is 1
# Index: 161
# ori/Test/Positive/514I66U8R27J.png: label is 1
# Index: 162
# ori/Test/Negative/KGRBBSK9RAIB.png: label is 0
# Index: 163
# ori/Test/Positive/2QFAB2TNI3CA.png: label is 1
# Index: 164
# ori/Test/Positive/3MZZ3QR10N8A.png: label is 1
# Index: 165

# %%
class JPEGToNumpy():
    def __call__(self, sample):
        #print("Check Point 1")
        imagenet_mean = np.array([0.485, 0.456, 0.406])
        imagenet_std = np.array([0.229, 0.224, 0.225])
        img = image.load_img(sample['jpeg_path'], target_size=(224, 224),
                             color_mode='rgb', interpolation='lanczos')
        img_array = np.asarray(img, dtype='uint8')
        img_array =  img_array / 255
        centered = np.subtract(img_array, imagenet_mean)
        standardized = np.divide(centered, imagenet_std)
        sample['image'] = img_array
        return sample

class AiSeverity:
    def __init__(self, device=None):
        self.transforms = transforms.Compose([
            JPEGToNumpy(),
            # CreateLungMask(device),
            # ApplyLungMask(constant_values=-1024)
        ])

    def __call__(self, jpeg_path):
        sample = {'jpeg_path': jpeg_path}
        sample = self.transforms(sample)
        return sample['image']

# Folder paths
normal_folder = 'ucsd/Train/Negative/'
pneumonia_folder = 'ucsd/Train/Positive/'
# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Set the random seed for reproducibility
np.random.seed(100)

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

train_samples = file_samples
train_labels = file_labels

# Folder paths
normal_folder = 'ucsd/Validation/Negative/'
pneumonia_folder = 'ucsd/Validation/Positive/'
# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Set the random seed for reproducibility
np.random.seed(100)

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

validation_samples = file_samples
validation_labels = file_labels

# Folder paths
normal_folder = 'ucsd/Test/Negative/'
pneumonia_folder = 'ucsd/Test/Positive/'

# Initialize an empty dictionary to store file names and labels
file_labels = {}
file_samples = {}

# Assign labels to PNEUMONIA files
pneumonia_files = os.listdir(pneumonia_folder)
for file_name in pneumonia_files:
    file_path = os.path.join(pneumonia_folder, file_name)
    file_labels[file_path] = 1

# Assign labels to NORMAL files
normal_files = os.listdir(normal_folder)
for file_name in normal_files:
    file_path = os.path.join(normal_folder, file_name)
    file_labels[file_path] = 0

# Call AiSeverity method
ai_severity = AiSeverity(device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
index = 0
items_list = list(file_labels.items())

# Shuffle the list of tuples using random.shuffle()
np.random.shuffle(items_list)

# Create a new dictionary from the shuffled list of tuples
file_labels = dict(items_list)

for file_path, label in file_labels.items():
    sample = ai_severity(file_path)
    print(f'{file_path}: label is {label}')
    file_samples[file_path] = sample
    index = index + 1
    print(f"Index: {index}")

test_samples = file_samples
test_labels = file_labels

BATCH_SIZE_TRAINING = 64
BATCH_SIZE_VALIDATION = 64
BATCH_SIZE_TESTING = 1

train_datagen = ImageDataGenerator(
fill_mode="nearest",
    validation_split=0.20,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,

)

test_datagen = ImageDataGenerator(
fill_mode="nearest",
    validation_split=0.20,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
)

train_image_list = [(train_samples[key], train_labels[key]) for key in train_samples.keys()]
validation_image_list = [(validation_samples[key], validation_labels[key]) for key in validation_samples.keys()]
test_image_list = [(test_samples[key], test_labels[key]) for key in test_samples.keys()]

# Split the image_list into training and validation sets
train_generator = train_datagen.flow(
    x=np.array([image for image, label in train_image_list]),
    y=[label for image, label in train_image_list],
    batch_size=BATCH_SIZE_TRAINING,
    shuffle=True,
    seed=60
)

valid_generator = train_datagen.flow(
    x=np.array([image for image, label in validation_image_list]),
    y=[label for image, label in validation_image_list],
    batch_size=BATCH_SIZE_VALIDATION,
    shuffle=True,
    seed=60
)

test_generator = test_datagen.flow(
    x=np.array([image for image, label in test_image_list]),
    y=[label for image, label in test_image_list],
    batch_size=BATCH_SIZE_TESTING,
    shuffle=False,
    seed=60
)
# Out:
# Streaming output truncated to the last 5000 lines.
# ucsd/Train/Positive/VIRUS-3884102-0002.jpeg: label is 1
# Index: 577
# ucsd/Train/Negative/NORMAL-5918516-0001.jpeg: label is 0
# Index: 578
# ucsd/Train/Positive/VIRUS-4655012-0001.jpeg: label is 1
# Index: 579
# ucsd/Train/Positive/VIRUS-3326238-0002.jpeg: label is 1
# Index: 580
# ucsd/Train/Positive/VIRUS-4979525-0001.jpeg: label is 1
# Index: 581
# ucsd/Train/Negative/NORMAL-5659176-0001.jpeg: label is 0
# Index: 582
# ucsd/Train/Negative/NORMAL-8290716-0001.jpeg: label is 0
# Index: 583
# ucsd/Train/Positive/VIRUS-6666172-0001.jpeg: label is 1
# Index: 584
# ucsd/Train/Positive/VIRUS-8175587-0002.jpeg: label is 1
# Index: 585
# ucsd/Train/Positive/VIRUS-8806791-0002.jpeg: label is 1
# Index: 586
# ucsd/Train/Positive/VIRUS-387616-0003.jpeg: label is 1
# Index: 587
# ucsd/Train/Positive/VIRUS-1352878-0006.jpeg: label is 1
# Index: 588
# ucsd/Train/Positive/VIRUS-2526622-0001.jpeg: label is 1
# Index: 589
# ucsd/Train/Positive/VIRUS-2111525-0002.jpeg: label is 1
# Index: 590
# ucsd/Train/Positive/VIRUS-463487-0012.jpeg: label is 1
# Index: 591
# ucsd/Train/Positive/VIRUS-3745681-0002.jpeg: label is 1
# Index: 592
# ucsd/Train/Negative/NORMAL-4119877-0001.jpeg: label is 0
# Index: 593
# ucsd/Train/Positive/VIRUS-5573469-0001.jpeg: label is 1
# Index: 594
# ucsd/Train/Positive/VIRUS-9044474-0007.jpeg: label is 1
# Index: 595
# ucsd/Train/Negative/NORMAL-5661793-0001.jpeg: label is 0
# Index: 596
# ucsd/Train/Positive/VIRUS-1129531-0002.jpeg: label is 1
# Index: 597
# ucsd/Train/Positive/VIRUS-8903181-0001.jpeg: label is 1
# Index: 598
# ucsd/Train/Positive/VIRUS-4467110-0002.jpeg: label is 1
# Index: 599
# ucsd/Train/Negative/NORMAL-2214391-0001.jpeg: label is 0
# Index: 600
# ucsd/Train/Negative/NORMAL-1803887-0001.jpeg: label is 0
# Index: 601
# ucsd/Train/Positive/VIRUS-8285776-0004.jpeg: label is 1
# Index: 602
# ucsd/Train/Negative/NORMAL-3168931-0001.jpeg: label is 0
# Index: 603
# ucsd/Train/Negative/NORMAL-6112892-0002.jpeg: label is 0
# Index: 604
# ucsd/Train/Negative/NORMAL-9482504-0002.jpeg: label is 0
# Index: 605
# ucsd/Train/Positive/VIRUS-1054331-0001.jpeg: label is 1
# Index: 606
# ucsd/Train/Positive/VIRUS-7533287-0002.jpeg: label is 1
# Index: 607
# ucsd/Train/Negative/NORMAL-1602427-0001.jpeg: label is 0
# Index: 587
# ucsd/Test/Positive/VIRUS-8688218-0002.jpeg: label is 1
# Index: 588
# ucsd/Test/Positive/VIRUS-6306189-0001.jpeg: label is 1
# Index: 589
# ucsd/Test/Negative/NORMAL-6137902-0001.jpeg: label is 0
# Index: 590
# ucsd/Test/Positive/VIRUS-6569688-0003.jpeg: label is 1
# Index: 591
# ucsd/Test/Positive/VIRUS-280992-0001.jpeg: label is 1
# Index: 592
# ucsd/Test/Positive/VIRUS-7193745-0002.jpeg: label is 1
# Index: 593
# ucsd/Test/Negative/NORMAL-4906464-0001.jpeg: label is 0
# Index: 594
# ucsd/Test/Negative/NORMAL-9386779-0001.jpeg: label is 0
# Index: 595
# ucsd/Test/Positive/VIRUS-9822795-0002.jpeg: label is 1
# Index: 596
# ucsd/Test/Negative/NORMAL-7605819-0001.jpeg: label is 0
# Index: 597
# ucsd/Test/Positive/VIRUS-5386176-0002.jpeg: label is 1
# Index: 598
# ucsd/Test/Positive/VIRUS-537555-0004.jpeg: label is 1
# Index: 599
# ucsd/Test/Positive/VIRUS-9613951-0001.jpeg: label is 1
# Index: 600
# ucsd/Test/Positive/VIRUS-6760822-0006.jpeg: label is 1
# Index: 601
# ucsd/Test/Negative/NORMAL-3907168-0001.jpeg: label is 0
# Index: 602
# ucsd/Test/Negative/NORMAL-7298793-0001.jpeg: label is 0
# Index: 603
# ucsd/Test/Positive/VIRUS-8093423-0002.jpeg: label is 1
# Index: 604
# ucsd/Test/Negative/NORMAL-5638457-0001.jpeg: label is 0
# Index: 605
# ucsd/Test/Negative/NORMAL-7333515-0002.jpeg: label is 0
# Index: 606
# ucsd/Test/Positive/VIRUS-414834-0002.jpeg: label is 1
# Index: 607
# ucsd/Test/Positive/VIRUS-3956374-0003.jpeg: label is 1
# Index: 608
# ucsd/Test/Positive/VIRUS-5289209-0002.jpeg: label is 1
# Index: 609
# ucsd/Test/Positive/VIRUS-7631316-0002.jpeg: label is 1
# Index: 610
# ucsd/Test/Positive/VIRUS-4178213-0002.jpeg: label is 1
# Index: 611
# ucsd/Test/Negative/NORMAL-1049278-0001.jpeg: label is 0
# Index: 612
# ucsd/Test/Negative/NORMAL-191707-0001.jpeg: label is 0
# Index: 613
# ucsd/Test/Positive/VIRUS-3194796-0003.jpeg: label is 1
# Index: 614
# ucsd/Test/Negative/NORMAL-7049415-0001.jpeg: label is 0
# Index: 615
# ucsd/Test/Positive/VIRUS-3698459-0001.jpeg: label is 1
# Index: 616

# %% [markdown]
# # Visualize

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 4, 1)
plt.imshow(train_generator[0][0][0,:,:,:])
plt.subplot(2, 4, 2)
plt.imshow(valid_generator[0][0][0,:,:,:])
plt.subplot(2, 4, 3)
plt.imshow(test_generator[0][0][0,:,:,:])
plt.subplot(2, 4, 4)
plt.imshow(train_generator[0][0][30,:,:,:])
plt.subplot(2, 4, 5)
plt.imshow(valid_generator[0][0][30,:,:,:])
plt.subplot(2, 4, 6)
plt.imshow(test_generator[5][0][0,:,:,:])
plt.subplot(2, 4, 7)
plt.imshow(train_generator[6][0][40,:,:,:])
plt.subplot(2, 4, 8)
plt.imshow(test_generator[6][0][0,:,:,:])
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 4, 1)
plt.imshow(train_generator[8][0][0,:,:,:])
plt.subplot(2, 4, 2)
plt.imshow(valid_generator[2][0][0,:,:,:])
plt.subplot(2, 4, 3)
plt.imshow(test_generator[6][0][0,:,:,:])
plt.subplot(2, 4, 4)
plt.imshow(train_generator[4][0][30,:,:,:])
plt.subplot(2, 4, 5)
plt.imshow(valid_generator[1][0][1,:,:,:])
plt.subplot(2, 4, 6)
plt.imshow(test_generator[3][0][0,:,:,:])
plt.subplot(2, 4, 7)
plt.imshow(train_generator[4][0][40,:,:,:])
plt.subplot(2, 4, 8)
plt.imshow(test_generator[5][0][0,:,:,:])
plt.show()

# %% [markdown]
# # Basic Transfer Learning 0

# %%
img_size = 224
dropout = 0
weights = "DenseNet_224_up_uncrop.h5"

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0)(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout)(x)
x = layers.Dense(128, activation='relu',)(x)
x = layers.Dropout(dropout)(x)
predictions= layers.Dense(1, activation='sigmoid',name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_2 (ZeroPadd  (None, 230, 230, 3)          0         ['input_2[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_3  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 1024)                 0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['flatten_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  131200    ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  last (Dense)                (None, 1)                    129       ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
# train the head of the network
print("training the head...")
history = model.fit(
        train_generator,
        epochs = 25,
        validation_data=valid_generator,
        callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
)
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# Out:
# training the head...
# Epoch 1/25
# 31/31 [==============================] - 40s 1s/step - loss: 0.6282 - accuracy: 0.6680 - auc: 0.7190 - precision: 0.6772 - recall: 0.6042 - val_loss: 0.5387 - val_accuracy: 0.8357 - val_auc: 0.9180 - val_precision: 0.8624 - val_recall: 0.7866 - lr: 0.0010
# 31/31 [==============================] - 27s 857ms/step - loss: 0.2811 - accuracy: 0.8887 - auc: 0.9504 - precision: 0.8849 - recall: 0.8859 - val_loss: 0.2991 - val_accuracy: 0.8682 - val_auc: 0.9469 - val_precision: 0.8919 - val_recall: 0.8285 - lr: 3.0000e-04
# Epoch 22/25
# 31/31 [==============================] - 27s 878ms/step - loss: 0.2736 - accuracy: 0.8963 - auc: 0.9530 - precision: 0.9033 - recall: 0.8806 - val_loss: 0.2790 - val_accuracy: 0.8884 - val_auc: 0.9523 - val_precision: 0.8740 - val_recall: 0.8996 - lr: 3.0000e-04
# Epoch 23/25
# 31/31 [==============================] - 27s 860ms/step - loss: 0.2812 - accuracy: 0.8902 - auc: 0.9504 - precision: 0.8969 - recall: 0.8743 - val_loss: 0.2922 - val_accuracy: 0.8803 - val_auc: 0.9493 - val_precision: 0.8543 - val_recall: 0.9079 - lr: 3.0000e-04
# Epoch 24/25
# 31/31 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.8882 - auc: 0.9503 - precision: 0.8905 - recall: 0.8775
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 31/31 [==============================] - 27s 859ms/step - loss: 0.2823 - accuracy: 0.8882 - auc: 0.9503 - precision: 0.8905 - recall: 0.8775 - val_loss: 0.2951 - val_accuracy: 0.8742 - val_auc: 0.9483 - val_precision: 0.8766 - val_recall: 0.8619 - lr: 3.0000e-04
# Epoch 25/25
# 31/31 [==============================] - 26s 853ms/step - loss: 0.2735 - accuracy: 0.8948 - auc: 0.9528 - precision: 0.8962 - recall: 0.8859 - val_loss: 0.2975 - val_accuracy: 0.8742 - val_auc: 0.9481 - val_precision: 0.8417 - val_recall: 0.9121 - lr: 9.0000e-05

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 13s 17ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8928571428571429
# 0.8926706265891563
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       317
#            1       0.89      0.89      0.89       299
#
#     accuracy                           0.89       616
#    macro avg       0.89      0.89      0.89       616
# weighted avg       0.89      0.89      0.89       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_basic_transfer_0_0.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 3s 17ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.593939393939394
# 0.5925925925925928
#               precision    recall  f1-score   support
#
#            0       0.59      0.67      0.63        84
#            1       0.60      0.52      0.56        81
#
#     accuracy                           0.59       165
#    macro avg       0.59      0.59      0.59       165
# weighted avg       0.59      0.59      0.59       165

# %% [markdown]
# # Basic Transfer Learning 0.3

# %%
img_size = 224
dropout = 0.3
weights = "DenseNet_224_up_uncrop.h5"

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0)(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout)(x)
x = layers.Dense(128, activation='relu',)(x)
x = layers.Dropout(dropout)(x)
predictions= layers.Dense(1, activation='sigmoid',name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_4 (ZeroPadd  (None, 230, 230, 3)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_4[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_5 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_5[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_5  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_2 (Flatten)         (None, 1024)                 0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dropout_7 (Dropout)         (None, 1024)                 0         ['flatten_2[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  131200    ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  last (Dense)                (None, 1)                    129       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
# train the head of the network
print("training the head...")
history = model.fit(
        train_generator,
        epochs = 25,
        validation_data=valid_generator,
        callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
)
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# Out:
# training the head...
# Epoch 1/25
# 31/31 [==============================] - 40s 966ms/step - loss: 0.6771 - accuracy: 0.5780 - auc: 0.6171 - precision: 0.5726 - recall: 0.5162 - val_loss: 0.5760 - val_accuracy: 0.7505 - val_auc: 0.9063 - val_precision: 0.8919 - val_recall: 0.5523 - lr: 0.0010
# Epoch 2/25
# 31/31 [==============================] - 28s 897ms/step - loss: 0.5674 - accuracy: 0.7102 - auc: 0.7922 - precision: 0.7081 - recall: 0.6859 - val_loss: 0.4774 - val_accuracy: 0.8235 - val_auc: 0.9168 - val_precision: 0.8585 - val_recall: 0.7615 - lr: 0.0010
# Epoch 3/25
# 31/31 [==============================] - 28s 910ms/step - loss: 0.5101 - accuracy: 0.7595 - auc: 0.8342 - precision: 0.7654 - recall: 0.7277 - val_loss: 0.4672 - val_accuracy: 0.7931 - val_auc: 0.9280 - val_precision: 0.7108 - val_recall: 0.9665 - lr: 0.0010
# Epoch 4/25
# 31/31 [==============================] - 27s 882ms/step - loss: 0.5020 - accuracy: 0.7631 - auc: 0.8369 - precision: 0.7566 - recall: 0.7550 - val_loss: 0.4076 - val_accuracy: 0.8458 - val_auc: 0.9298 - val_precision: 0.8791 - val_recall: 0.7908 - lr: 0.0010
# Epoch 5/25
# 31/31 [==============================] - 28s 913ms/step - loss: 0.4601 - accuracy: 0.7834 - auc: 0.8696 - precision: 0.7799 - recall: 0.7717 - val_loss: 0.3783 - val_accuracy: 0.8499 - val_auc: 0.9323 - val_precision: 0.8634 - val_recall: 0.8201 - lr: 0.0010
# Epoch 6/25
# 31/31 [==============================] - 27s 871ms/step - loss: 0.4484 - accuracy: 0.7895 - auc: 0.8710 - precision: 0.7815 - recall: 0.7864 - val_loss: 0.3865 - val_accuracy: 0.8458 - val_auc: 0.9243 - val_precision: 0.8655 - val_recall: 0.8075 - lr: 0.0010
# Epoch 7/25
# 31/31 [==============================] - 28s 904ms/step - loss: 0.4470 - accuracy: 0.7982 - auc: 0.8742 - precision: 0.7870 - recall: 0.8010 - val_loss: 0.3453 - val_accuracy: 0.8763 - val_auc: 0.9443 - val_precision: 0.8708 - val_recall: 0.8745 - lr: 0.0010
# Epoch 8/25
# 31/31 [==============================] - 27s 888ms/step - loss: 0.4415 - accuracy: 0.8099 - auc: 0.8790 - precision: 0.8068 - recall: 0.8000 - val_loss: 0.3583 - val_accuracy: 0.8641 - val_auc: 0.9339 - val_precision: 0.8496 - val_recall: 0.8745 - lr: 0.0010
# Epoch 9/25
# 31/31 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8078 - auc: 0.8872 - precision: 0.7996 - recall: 0.8063
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 31/31 [==============================] - 27s 882ms/step - loss: 0.4238 - accuracy: 0.8078 - auc: 0.8872 - precision: 0.7996 - recall: 0.8063 - val_loss: 0.3631 - val_accuracy: 0.8499 - val_auc: 0.9364 - val_precision: 0.8947 - val_recall: 0.7824 - lr: 0.0010
# Epoch 10/25
# 31/31 [==============================] - 28s 892ms/step - loss: 0.4347 - accuracy: 0.7911 - auc: 0.8805 - precision: 0.7833 - recall: 0.7874 - val_loss: 0.3469 - val_accuracy: 0.8641 - val_auc: 0.9377 - val_precision: 0.8707 - val_recall: 0.8452 - lr: 3.0000e-04

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 12s 17ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8733766233766234
# 0.8724138294841903
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       317
#            1       0.89      0.84      0.87       299
#
#     accuracy                           0.87       616
#    macro avg       0.87      0.87      0.87       616
# weighted avg       0.87      0.87      0.87       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_basic_transfer_0_0.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 3s 17ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5636363636363636
# 0.5610670194003528
#               precision    recall  f1-score   support
#
#            0       0.56      0.70      0.62        84
#            1       0.58      0.42      0.49        81
#
#     accuracy                           0.56       165
#    macro avg       0.57      0.56      0.55       165
# weighted avg       0.57      0.56      0.55       165

# %% [markdown]
# # Basic Transfer Learning 0.6

# %%
img_size = 224
dropout = 0.6
weights = "DenseNet_224_up_uncrop.h5"

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0)(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout)(x)
x = layers.Dense(128, activation='relu',)(x)
x = layers.Dropout(dropout)(x)
predictions= layers.Dense(1, activation='sigmoid',name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_6 (ZeroPadd  (None, 230, 230, 3)          0         ['input_4[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_6[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_7 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_7[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_7  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_3 (Flatten)         (None, 1024)                 0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  dropout_10 (Dropout)        (None, 1024)                 0         ['flatten_3[0][0]']
#
#  dense_3 (Dense)             (None, 128)                  131200    ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['dense_3[0][0]']
#
#  last (Dense)                (None, 1)                    129       ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
# train the head of the network
print("training the head...")
history = model.fit(
        train_generator,
        epochs = 25,
        validation_data=valid_generator,
        callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
)
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# Out:
# training the head...
# Epoch 1/25
# 31/31 [==============================] - 38s 1s/step - loss: 0.7304 - accuracy: 0.5455 - auc: 0.5598 - precision: 0.5353 - recall: 0.4848 - val_loss: 0.6539 - val_accuracy: 0.5396 - val_auc: 0.9225 - val_precision: 0.5129 - val_recall: 1.0000 - lr: 0.0010
# Epoch 2/25
# 31/31 [==============================] - 28s 903ms/step - loss: 0.6576 - accuracy: 0.6065 - auc: 0.6519 - precision: 0.5926 - recall: 0.6063 - val_loss: 0.5911 - val_accuracy: 0.7992 - val_auc: 0.9343 - val_precision: 0.9545 - val_recall: 0.6151 - lr: 0.0010
# Epoch 3/25
# 31/31 [==============================] - 28s 894ms/step - loss: 0.6380 - accuracy: 0.6345 - auc: 0.6863 - precision: 0.6263 - recall: 0.6126 - val_loss: 0.5724 - val_accuracy: 0.7708 - val_auc: 0.9319 - val_precision: 0.9565 - val_recall: 0.5523 - lr: 0.0010
# Epoch 4/25
# Epoch 14/25
# 31/31 [==============================] - 28s 891ms/step - loss: 0.5412 - accuracy: 0.7260 - auc: 0.8029 - precision: 0.7199 - recall: 0.7131 - val_loss: 0.4466 - val_accuracy: 0.8621 - val_auc: 0.9363 - val_precision: 0.8608 - val_recall: 0.8536 - lr: 3.0000e-04
# Epoch 15/25
# 31/31 [==============================] - 27s 880ms/step - loss: 0.5484 - accuracy: 0.7224 - auc: 0.7953 - precision: 0.7270 - recall: 0.6859 - val_loss: 0.4411 - val_accuracy: 0.8661 - val_auc: 0.9441 - val_precision: 0.8879 - val_recall: 0.8285 - lr: 3.0000e-04
# Epoch 16/25
# 31/31 [==============================] - 28s 897ms/step - loss: 0.5382 - accuracy: 0.7285 - auc: 0.8042 - precision: 0.7200 - recall: 0.7215 - val_loss: 0.4270 - val_accuracy: 0.8600 - val_auc: 0.9411 - val_precision: 0.8728 - val_recall: 0.8326 - lr: 3.0000e-04
# Epoch 17/25
# 31/31 [==============================] - 28s 909ms/step - loss: 0.5320 - accuracy: 0.7321 - auc: 0.8103 - precision: 0.7211 - recall: 0.7309 - val_loss: 0.4127 - val_accuracy: 0.8641 - val_auc: 0.9474 - val_precision: 0.9135 - val_recall: 0.7950 - lr: 3.0000e-04
# Epoch 18/25
# 31/31 [==============================] - 27s 873ms/step - loss: 0.5540 - accuracy: 0.7234 - auc: 0.7911 - precision: 0.7165 - recall: 0.7120 - val_loss: 0.4336 - val_accuracy: 0.8580 - val_auc: 0.9357 - val_precision: 0.8477 - val_recall: 0.8619 - lr: 3.0000e-04
# Epoch 19/25
# 31/31 [==============================] - ETA: 0s - loss: 0.5395 - accuracy: 0.7346 - auc: 0.8049 - precision: 0.7207 - recall: 0.7403
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 31/31 [==============================] - 27s 868ms/step - loss: 0.5395 - accuracy: 0.7346 - auc: 0.8049 - precision: 0.7207 - recall: 0.7403 - val_loss: 0.4489 - val_accuracy: 0.8438 - val_auc: 0.9319 - val_precision: 0.8716 - val_recall: 0.7950 - lr: 3.0000e-04
# Epoch 20/25
# 31/31 [==============================] - 27s 888ms/step - loss: 0.5392 - accuracy: 0.7168 - auc: 0.8016 - precision: 0.7216 - recall: 0.6785 - val_loss: 0.4459 - val_accuracy: 0.8519 - val_auc: 0.9279 - val_precision: 0.8374 - val_recall: 0.8619 - lr: 9.0000e-05

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 13s 18ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8782467532467533
# 0.8778103668379351
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       317
#            1       0.88      0.86      0.87       299
#
#     accuracy                           0.88       616
#    macro avg       0.88      0.88      0.88       616
# weighted avg       0.88      0.88      0.88       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_basic_transfer_0_0.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 3s 18ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5818181818181818
# 0.5798059964726632
#               precision    recall  f1-score   support
#
#            0       0.57      0.69      0.63        84
#            1       0.59      0.47      0.52        81
#
#     accuracy                           0.58       165
#    macro avg       0.58      0.58      0.58       165
# weighted avg       0.58      0.58      0.58       165

# %% [markdown]
# # Basic Transfer Learning 0.9

# %%
img_size = 224
dropout = 0.9
weights = "DenseNet_224_up_uncrop.h5"

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0)(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dropout(dropout)(x)
x = layers.Dense(128, activation='relu',)(x)
x = layers.Dropout(dropout)(x)
predictions= layers.Dense(1, activation='sigmoid',name='last')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1024)                 0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['flatten[0][0]']
#
#  dense (Dense)               (None, 128)                  131200    ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense[0][0]']
#
#  last (Dense)                (None, 1)                    129       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
# train the head of the network
print("training the head...")
history = model.fit(
        train_generator,
        epochs = 25,
        validation_data=valid_generator,
        callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
)
# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(history.history)
# Out:
# training the head...
# Epoch 1/25
# 31/31 [==============================] - 64s 1s/step - loss: 1.7761 - accuracy: 0.5150 - auc: 0.5020 - precision: 0.5005 - recall: 0.5497 - val_loss: 0.6980 - val_accuracy: 0.5152 - val_auc: 0.7717 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/25
# 31/31 [==============================] - 34s 1s/step - loss: 1.2066 - accuracy: 0.4825 - auc: 0.4820 - precision: 0.4644 - recall: 0.4304 - val_loss: 0.6906 - val_accuracy: 0.5152 - val_auc: 0.6600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 3/25
# 31/31 [==============================] - 36s 1s/step - loss: 0.8808 - accuracy: 0.5369 - auc: 0.5448 - precision: 0.5269 - recall: 0.4513 - val_loss: 0.6927 - val_accuracy: 0.5152 - val_auc: 0.5020 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/25
# 31/31 [==============================] - ETA: 0s - loss: 0.8236 - accuracy: 0.5043 - auc: 0.5112 - precision: 0.4882 - recall: 0.4335
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 31/31 [==============================] - 34s 1s/step - loss: 0.8236 - accuracy: 0.5043 - auc: 0.5112 - precision: 0.4882 - recall: 0.4335 - val_loss: 0.6924 - val_accuracy: 0.5152 - val_auc: 0.5042 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 5/25
# 31/31 [==============================] - 34s 1s/step - loss: 0.7767 - accuracy: 0.5277 - auc: 0.5283 - precision: 0.5167 - recall: 0.4220 - val_loss: 0.6927 - val_accuracy: 0.5152 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 3.0000e-04

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 74s 114ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5146103896103896
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68       317
#            1       0.00      0.00      0.00       299
#
#     accuracy                           0.51       616
#    macro avg       0.26      0.50      0.34       616
# weighted avg       0.26      0.51      0.35       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_basic_transfer_0_0.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 6s 34ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.509090909090909
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67        84
#            1       0.00      0.00      0.00        81
#
#     accuracy                           0.51       165
#    macro avg       0.25      0.50      0.34       165
# weighted avg       0.26      0.51      0.34       165

# %% [markdown]
# # New Transfer Learning 0 Iterations = 0

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0
weights = "DenseNet_224_up_uncrop.h5"
iterations = 0

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
model.summary()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))

# %% [markdown]
# # New Transfer Learning 0.3 Iterations = 10

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.3
weights = "DenseNet_224_up_uncrop.h5"
iterations = 10

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  custom_dropout_1 (CustomDr  (None, 1024)                 0         ['global_average_pooling2d_1[0
#  opout)                                                             ][0]']
#
#  dense (Dense)               (None, 128)                  131200    ['custom_dropout_1[0][0]']
#
#  custom_dropout_2 (CustomDr  (None, 128)                  0         ['dense[0][0]']
#  opout)
#
#  last (Dense)                (None, 1)                    129       ['custom_dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider
# Out:
# 8

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 41s 1s/step - loss: 0.6813 - accuracy: 0.5821 - auc: 0.6462 - precision: 0.5699 - recall: 0.5675 - val_loss: 0.5734 - val_accuracy: 0.7850 - val_auc: 0.9209 - val_precision: 0.9182 - val_recall: 0.6109 - lr: 0.0010
# Epochs 22
# 31/31 [==============================] - 37s 991ms/step - loss: 0.3481 - accuracy: 0.8643 - auc: 0.9262 - precision: 0.8715 - recall: 0.8450 - val_loss: 0.3299 - val_accuracy: 0.8621 - val_auc: 0.9334 - val_precision: 0.8434 - val_recall: 0.8787 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 38s 999ms/step - loss: 0.3485 - accuracy: 0.8556 - auc: 0.9263 - precision: 0.8596 - recall: 0.8398 - val_loss: 0.3470 - val_accuracy: 0.8438 - val_auc: 0.9441 - val_precision: 0.7812 - val_recall: 0.9414 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 38s 986ms/step - loss: 0.3407 - accuracy: 0.8612 - auc: 0.9290 - precision: 0.8620 - recall: 0.8503 - val_loss: 0.3943 - val_accuracy: 0.8276 - val_auc: 0.9414 - val_precision: 0.7550 - val_recall: 0.9540 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 39s 983ms/step - loss: 0.3463 - accuracy: 0.8561 - auc: 0.9264 - precision: 0.8597 - recall: 0.8408 - val_loss: 0.3230 - val_accuracy: 0.8641 - val_auc: 0.9423 - val_precision: 0.9019 - val_recall: 0.8075 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 16s 22ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8831168831168831
# 0.8812128757266597
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89       317
#            1       0.93      0.82      0.87       299
#
#     accuracy                           0.88       616
#    macro avg       0.89      0.88      0.88       616
# weighted avg       0.89      0.88      0.88       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 4s 21ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5818181818181818
# 0.5778218694885362
#               precision    recall  f1-score   support
#
#            0       0.56      0.80      0.66        84
#            1       0.63      0.36      0.46        81
#
#     accuracy                           0.58       165
#    macro avg       0.60      0.58      0.56       165
# weighted avg       0.60      0.58      0.56       165

# %% [markdown]
# # New Transfer Learning 0.6 Iterations = 10

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.6
weights = "DenseNet_224_up_uncrop.h5"
iterations = 10

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_2 (ZeroPadd  (None, 230, 230, 3)          0         ['input_2[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_3  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  custom_dropout_4 (CustomDr  (None, 1024)                 0         ['global_average_pooling2d_3[0
#  opout)                                                             ][0]']
#
#  dense_1 (Dense)             (None, 128)                  131200    ['custom_dropout_4[0][0]']
#
#  custom_dropout_5 (CustomDr  (None, 128)                  0         ['dense_1[0][0]']
#  opout)
#
#  last (Dense)                (None, 1)                    129       ['custom_dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider
# Out:
# 8

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 38s 989ms/step - loss: 0.7063 - accuracy: 0.5836 - auc: 0.6127 - precision: 0.5785 - recall: 0.5246 - val_loss: 0.8223 - val_accuracy: 0.4848 - val_auc: 0.9095 - val_precision: 0.4848 - val_recall: 1.0000 - lr: 0.0010
# Epochs 2
# 31/31 [==============================] - 37s 979ms/step - loss: 0.6208 - accuracy: 0.6655 - auc: 0.7223 - precision: 0.6634 - recall: 0.6314 - val_loss: 0.5590 - val_accuracy: 0.6836 - val_auc: 0.9123 - val_precision: 0.6084 - val_recall: 0.9749 - lr: 0.0010
# Epochs 3
# 31/31 [==============================] - 37s 987ms/step - loss: 0.5517 - accuracy: 0.7184 - auc: 0.7975 - precision: 0.7078 - recall: 0.7152 - val_loss: 0.4541 - val_accuracy: 0.8540 - val_auc: 0.9343 - val_precision: 0.8711 - val_recall: 0.8201 - lr: 0.0010
# Epochs 4
# 31/31 [==============================] - 44s 1s/step - loss: 0.5166 - accuracy: 0.7728 - auc: 0.8338 - precision: 0.7640 - recall: 0.7696 - val_loss: 0.4126 - val_accuracy: 0.8458 - val_auc: 0.9364 - val_precision: 0.8354 - val_recall: 0.8494 - lr: 0.0010
# Epochs 5
# 31/31 [==============================] - 37s 974ms/step - loss: 0.4568 - accuracy: 0.8129 - auc: 0.8750 - precision: 0.8029 - recall: 0.8147 - val_loss: 0.5453 - val_accuracy: 0.6876 - val_auc: 0.9307 - val_precision: 0.9775 - val_recall: 0.3640 - lr: 0.0010
# Epochs 16
# 31/31 [==============================] - 38s 1s/step - loss: 0.3619 - accuracy: 0.8551 - auc: 0.9197 - precision: 0.8468 - recall: 0.8565 - val_loss: 0.3168 - val_accuracy: 0.8702 - val_auc: 0.9407 - val_precision: 0.8723 - val_recall: 0.8577 - lr: 0.0010
# Epochs 17
# 31/31 [==============================] - 38s 1s/step - loss: 0.3526 - accuracy: 0.8602 - auc: 0.9229 - precision: 0.8505 - recall: 0.8639 - val_loss: 0.4274 - val_accuracy: 0.8053 - val_auc: 0.9399 - val_precision: 0.7284 - val_recall: 0.9540 - lr: 0.0010
# Epochs 18
# 31/31 [==============================] - 38s 994ms/step - loss: 0.3678 - accuracy: 0.8460 - auc: 0.9179 - precision: 0.8490 - recall: 0.8304 - val_loss: 0.3344 - val_accuracy: 0.8641 - val_auc: 0.9325 - val_precision: 0.8413 - val_recall: 0.8870 - lr: 0.0010
# Epochs 19
# 31/31 [==============================] - 38s 988ms/step - loss: 0.3625 - accuracy: 0.8480 - auc: 0.9200 - precision: 0.8431 - recall: 0.8440 - val_loss: 0.3336 - val_accuracy: 0.8458 - val_auc: 0.9371 - val_precision: 0.8123 - val_recall: 0.8870 - lr: 0.0010
# Epochs 20
# 31/31 [==============================] - 38s 994ms/step - loss: 0.3422 - accuracy: 0.8516 - auc: 0.9285 - precision: 0.8561 - recall: 0.8346 - val_loss: 0.4153 - val_accuracy: 0.8154 - val_auc: 0.9421 - val_precision: 0.9353 - val_recall: 0.6653 - lr: 0.0010
# Epochs 21
# 31/31 [==============================] - 37s 988ms/step - loss: 0.3535 - accuracy: 0.8510 - auc: 0.9242 - precision: 0.8371 - recall: 0.8607 - val_loss: 0.3606 - val_accuracy: 0.8438 - val_auc: 0.9440 - val_precision: 0.9355 - val_recall: 0.7280 - lr: 0.0010
# Epochs 22
# 31/31 [==============================] - 40s 981ms/step - loss: 0.3532 - accuracy: 0.8648 - auc: 0.9235 - precision: 0.8548 - recall: 0.8691 - val_loss: 0.3357 - val_accuracy: 0.8641 - val_auc: 0.9423 - val_precision: 0.9216 - val_recall: 0.7866 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 38s 1s/step - loss: 0.3557 - accuracy: 0.8587 - auc: 0.9235 - precision: 0.8493 - recall: 0.8618 - val_loss: 0.3468 - val_accuracy: 0.8519 - val_auc: 0.9544 - val_precision: 0.7785 - val_recall: 0.9707 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 38s 1s/step - loss: 0.3450 - accuracy: 0.8607 - auc: 0.9277 - precision: 0.8650 - recall: 0.8450 - val_loss: 0.3136 - val_accuracy: 0.8722 - val_auc: 0.9408 - val_precision: 0.8761 - val_recall: 0.8577 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 38s 1s/step - loss: 0.3511 - accuracy: 0.8541 - auc: 0.9253 - precision: 0.8576 - recall: 0.8387 - val_loss: 0.3018 - val_accuracy: 0.8722 - val_auc: 0.9457 - val_precision: 0.8607 - val_recall: 0.8787 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 15s 21ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8863636363636364
# 0.885791755905595
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89       317
#            1       0.90      0.87      0.88       299
#
#     accuracy                           0.89       616
#    macro avg       0.89      0.89      0.89       616
# weighted avg       0.89      0.89      0.89       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 4s 22ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5454545454545454
# 0.5427689594356261
#               precision    recall  f1-score   support
#
#            0       0.54      0.69      0.61        84
#            1       0.55      0.40      0.46        81
#
#     accuracy                           0.55       165
#    macro avg       0.55      0.54      0.53       165
# weighted avg       0.55      0.55      0.54       165

# %% [markdown]
# # New Transfer Learning 0.9 Iterations = 10

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.9
weights = "DenseNet_224_up_uncrop.h5"
iterations = 10

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_4 (ZeroPadd  (None, 230, 230, 3)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_4[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_5 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_5[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_5  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  custom_dropout_7 (CustomDr  (None, 1024)                 0         ['global_average_pooling2d_5[0
#  opout)                                                             ][0]']
#
#  dense_2 (Dense)             (None, 128)                  131200    ['custom_dropout_7[0][0]']
#
#  custom_dropout_8 (CustomDr  (None, 128)                  0         ['dense_2[0][0]']
#  opout)
#
#  last (Dense)                (None, 1)                    129       ['custom_dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider
# Out:
# 8

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 37s 968ms/step - loss: 0.6866 - accuracy: 0.5887 - auc: 0.6422 - precision: 0.5818 - recall: 0.5435 - val_loss: 0.5742 - val_accuracy: 0.7769 - val_auc: 0.9155 - val_precision: 0.9388 - val_recall: 0.5774 - lr: 0.0010
# Epochs 2
# 31/31 [==============================] - 37s 969ms/step - loss: 0.6053 - accuracy: 0.6940 - auc: 0.7708 - precision: 0.6933 - recall: 0.6628 - val_loss: 0.5089 - val_accuracy: 0.8235 - val_auc: 0.9181 - val_precision: 0.8838 - val_recall: 0.7322 - lr: 0.0010
# Epochs 3
# 31/31 [==============================] - 37s 979ms/step - loss: 0.5519 - accuracy: 0.7361 - auc: 0.8111 - precision: 0.7319 - recall: 0.7204 - val_loss: 0.4855 - val_accuracy: 0.8012 - val_auc: 0.9267 - val_precision: 0.7183 - val_recall: 0.9707 - lr: 0.0010
# Epochs 4
# 31/31 [==============================] - 37s 970ms/step - loss: 0.5038 - accuracy: 0.7636 - auc: 0.8400 - precision: 0.7734 - recall: 0.7257 - val_loss: 0.4924 - val_accuracy: 0.7424 - val_auc: 0.9259 - val_precision: 0.6591 - val_recall: 0.9707 - lr: 0.0010
# Epochs 5
# 31/31 [==============================] - 37s 974ms/step - loss: 0.4666 - accuracy: 0.7850 - auc: 0.8656 - precision: 0.7854 - recall: 0.7665 - val_loss: 0.4576 - val_accuracy: 0.7890 - val_auc: 0.9240 - val_precision: 0.9592 - val_recall: 0.5900 - lr: 0.0010
# Epochs 6
# 31/31 [==============================] - 38s 989ms/step - loss: 0.4313 - accuracy: 0.8205 - auc: 0.8890 - precision: 0.8097 - recall: 0.8241 - val_loss: 0.3823 - val_accuracy: 0.8580 - val_auc: 0.9274 - val_precision: 0.8596 - val_recall: 0.8452 - lr: 0.0010
# Epochs 7
# 31/31 [==============================] - 38s 1s/step - loss: 0.4100 - accuracy: 0.8297 - auc: 0.9004 - precision: 0.8150 - recall: 0.8398 - val_loss: 0.3624 - val_accuracy: 0.8458 - val_auc: 0.9349 - val_precision: 0.8052 - val_recall: 0.8996 - lr: 0.0010
# Epochs 8
# 31/31 [==============================] - 37s 974ms/step - loss: 0.4114 - accuracy: 0.8175 - auc: 0.8947 - precision: 0.8225 - recall: 0.7958 - val_loss: 0.4134 - val_accuracy: 0.8114 - val_auc: 0.9245 - val_precision: 0.7401 - val_recall: 0.9414 - lr: 0.0010
# Epochs 9
# 31/31 [==============================] - 37s 981ms/step - loss: 0.4109 - accuracy: 0.8246 - auc: 0.8956 - precision: 0.8294 - recall: 0.8042 - val_loss: 0.3268 - val_accuracy: 0.8824 - val_auc: 0.9475 - val_precision: 0.8884 - val_recall: 0.8661 - lr: 0.0010
# Epochs 20
# 31/31 [==============================] - 37s 987ms/step - loss: 0.3610 - accuracy: 0.8561 - auc: 0.9186 - precision: 0.8597 - recall: 0.8408 - val_loss: 0.3588 - val_accuracy: 0.8357 - val_auc: 0.9469 - val_precision: 0.9389 - val_recall: 0.7071 - lr: 0.0010
# Epochs 21
# 31/31 [==============================] - 37s 982ms/step - loss: 0.3392 - accuracy: 0.8536 - auc: 0.9296 - precision: 0.8463 - recall: 0.8534 - val_loss: 0.3942 - val_accuracy: 0.8215 - val_auc: 0.9351 - val_precision: 0.7492 - val_recall: 0.9498 - lr: 0.0010
# Epochs 22
# 31/31 [==============================] - 37s 972ms/step - loss: 0.3383 - accuracy: 0.8668 - auc: 0.9281 - precision: 0.8754 - recall: 0.8461 - val_loss: 0.3596 - val_accuracy: 0.8479 - val_auc: 0.9411 - val_precision: 0.7867 - val_recall: 0.9414 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 38s 1s/step - loss: 0.3454 - accuracy: 0.8531 - auc: 0.9253 - precision: 0.8620 - recall: 0.8304 - val_loss: 0.3050 - val_accuracy: 0.8763 - val_auc: 0.9447 - val_precision: 0.8589 - val_recall: 0.8912 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 37s 987ms/step - loss: 0.3459 - accuracy: 0.8556 - auc: 0.9247 - precision: 0.8707 - recall: 0.8251 - val_loss: 0.3346 - val_accuracy: 0.8702 - val_auc: 0.9429 - val_precision: 0.8253 - val_recall: 0.9289 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 37s 992ms/step - loss: 0.3442 - accuracy: 0.8571 - auc: 0.9265 - precision: 0.8624 - recall: 0.8398 - val_loss: 0.3803 - val_accuracy: 0.8438 - val_auc: 0.9386 - val_precision: 0.7812 - val_recall: 0.9414 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 15s 21ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8327922077922078
# 0.8357353111844951
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       317
#            1       0.77      0.94      0.84       299
#
#     accuracy                           0.83       616
#    macro avg       0.85      0.84      0.83       616
# weighted avg       0.85      0.83      0.83       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(train_generator_test))
combined_prediction.extend(model.predict(valid_generator_test))
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(train_generator_test)):
    batch_images, batch_labels = train_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
for i in range(len(valid_generator_test)):
    batch_images, batch_labels = valid_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# 9/9 [==============================] - 7s 796ms/step
# 3/3 [==============================] - 2s 803ms/step
# 165/165 [==============================] - 3s 21ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.528554070473876
# 0.5310557905432548
#               precision    recall  f1-score   support
#
#            0       0.55      0.39      0.46       419
#            1       0.52      0.67      0.58       404
#
#     accuracy                           0.53       823
#    macro avg       0.53      0.53      0.52       823
# weighted avg       0.53      0.53      0.52       823

# %% [markdown]
# # New Transfer Learning 0.3 Iterations = 20

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.3
weights = "DenseNet_224_up_uncrop.h5"
iterations = 20

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  custom_dropout_1 (CustomDr  (None, 1024)                 0         ['global_average_pooling2d_1[0
#  opout)                                                             ][0]']
#
#  dense (Dense)               (None, 128)                  131200    ['custom_dropout_1[0][0]']
#
#  custom_dropout_2 (CustomDr  (None, 128)                  0         ['dense[0][0]']
#  opout)
#
#  last (Dense)                (None, 1)                    129       ['custom_dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider
# Out:
# 8

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 40s 999ms/step - loss: 0.6909 - accuracy: 0.6177 - auc: 0.6359 - precision: 0.6160 - recall: 0.5644 - val_loss: 0.6113 - val_accuracy: 0.6491 - val_auc: 0.9206 - val_precision: 0.5825 - val_recall: 0.9749 - lr: 0.0010
# Epochs 2
# 31/31 [==============================] - 39s 1s/step - loss: 0.3490 - accuracy: 0.8658 - auc: 0.9280 - precision: 0.8687 - recall: 0.8524 - val_loss: 0.4155 - val_accuracy: 0.8134 - val_auc: 0.9412 - val_precision: 0.7319 - val_recall: 0.9707 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 41s 1s/step - loss: 0.3471 - accuracy: 0.8516 - auc: 0.9268 - precision: 0.8471 - recall: 0.8471 - val_loss: 0.4151 - val_accuracy: 0.8276 - val_auc: 0.9417 - val_precision: 0.9425 - val_recall: 0.6862 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 41s 1s/step - loss: 0.3410 - accuracy: 0.8607 - auc: 0.9302 - precision: 0.8565 - recall: 0.8565 - val_loss: 0.3021 - val_accuracy: 0.8702 - val_auc: 0.9446 - val_precision: 0.8571 - val_recall: 0.8787 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 40s 1s/step - loss: 0.3324 - accuracy: 0.8683 - auc: 0.9324 - precision: 0.8580 - recall: 0.8733 - val_loss: 0.3647 - val_accuracy: 0.8458 - val_auc: 0.9407 - val_precision: 0.9223 - val_recall: 0.7448 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 39s 58ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8327922077922078
# 0.8294683645801462
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       317
#            1       0.92      0.72      0.81       299
#
#     accuracy                           0.83       616
#    macro avg       0.85      0.83      0.83       616
# weighted avg       0.85      0.83      0.83       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 8s 46ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5575757575757576
# 0.5522486772486772
#               precision    recall  f1-score   support
#
#            0       0.54      0.85      0.66        84
#            1       0.62      0.26      0.37        81
#
#     accuracy                           0.56       165
#    macro avg       0.58      0.55      0.51       165
# weighted avg       0.58      0.56      0.52       165

# %% [markdown]
# # New Transfer Learning 0.6 Iterations = 20

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.6
weights = "DenseNet_224_up_uncrop.h5"
iterations = 20

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Compiling the model...

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_2 (ZeroPadd  (None, 230, 230, 3)          0         ['input_2[0][0]']
#  ing2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
#  rmalization)
#
# ...
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_3  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  custom_dropout_4 (CustomDr  (None, 1024)                 0         ['global_average_pooling2d_3[0
#  opout)                                                             ][0]']
#
#  dense_1 (Dense)             (None, 128)                  131200    ['custom_dropout_4[0][0]']
#
#  custom_dropout_5 (CustomDr  (None, 128)                  0         ['dense_1[0][0]']
#  opout)
#
#  last (Dense)                (None, 1)                    129       ['custom_dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 7168833 (27.35 MB)
# Trainable params: 131329 (513.00 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider
# Out:
# 8

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 42s 1s/step - loss: 0.6916 - accuracy: 0.5923 - auc: 0.6292 - precision: 0.5943 - recall: 0.5047 - val_loss: 0.6011 - val_accuracy: 0.8235 - val_auc: 0.9232 - val_precision: 0.7585 - val_recall: 0.9331 - lr: 0.0010
# Epochs 2
# 31/31 [==============================] - 41s 1s/step - loss: 0.6070 - accuracy: 0.6726 - auc: 0.7562 - precision: 0.6769 - recall: 0.6230 - val_loss: 0.5324 - val_accuracy: 0.8418 - val_auc: 0.9272 - val_precision: 0.8313 - val_recall: 0.8452 - lr: 0.0010
# Epochs 3
# 31/31 [==============================] - 40s 1s/step - loss: 0.5372 - accuracy: 0.7367 - auc: 0.8166 - precision: 0.7393 - recall: 0.7068 - val_loss: 0.4676 - val_accuracy: 0.8337 - val_auc: 0.9329 - val_precision: 0.9290 - val_recall: 0.7113 - lr: 0.0010
# Epochs 4
# 31/31 [==============================] - 40s 1s/step - loss: 0.4865 - accuracy: 0.7692 - auc: 0.8562 - precision: 0.7673 - recall: 0.7529 - val_loss: 0.4383 - val_accuracy: 0.8195 - val_auc: 0.9316 - val_precision: 0.9213 - val_recall: 0.6862 - lr: 0.0010
# Epochs 5
# 31/31 [==============================] - 40s 1s/step - loss: 0.4467 - accuracy: 0.8160 - auc: 0.8838 - precision: 0.8118 - recall: 0.8084 - val_loss: 0.4618 - val_accuracy: 0.7586 - val_auc: 0.9370 - val_precision: 0.6744 - val_recall: 0.9707 - lr: 0.0010
# Epochs 6
# 31/31 [==============================] - 39s 1s/step - loss: 0.3564 - accuracy: 0.8465 - auc: 0.9231 - precision: 0.8448 - recall: 0.8377 - val_loss: 0.3864 - val_accuracy: 0.8195 - val_auc: 0.9415 - val_precision: 0.7404 - val_recall: 0.9665 - lr: 0.0010
# Epochs 17
# 31/31 [==============================] - 40s 1s/step - loss: 0.3444 - accuracy: 0.8592 - auc: 0.9277 - precision: 0.8568 - recall: 0.8524 - val_loss: 0.3640 - val_accuracy: 0.8458 - val_auc: 0.9379 - val_precision: 0.7840 - val_recall: 0.9414 - lr: 0.0010
# Epochs 18
# 31/31 [==============================] - 41s 1s/step - loss: 0.3530 - accuracy: 0.8531 - auc: 0.9252 - precision: 0.8505 - recall: 0.8461 - val_loss: 0.3664 - val_accuracy: 0.8377 - val_auc: 0.9509 - val_precision: 0.9595 - val_recall: 0.6946 - lr: 0.0010
# Epochs 19
# 31/31 [==============================] - 41s 1s/step - loss: 0.3603 - accuracy: 0.8485 - auc: 0.9200 - precision: 0.8369 - recall: 0.8545 - val_loss: 0.3243 - val_accuracy: 0.8702 - val_auc: 0.9397 - val_precision: 0.8378 - val_recall: 0.9079 - lr: 0.0010
# Epochs 20
# 31/31 [==============================] - 42s 1s/step - loss: 0.3582 - accuracy: 0.8622 - auc: 0.9247 - precision: 0.8654 - recall: 0.8482 - val_loss: 0.3330 - val_accuracy: 0.8540 - val_auc: 0.9402 - val_precision: 0.8104 - val_recall: 0.9121 - lr: 0.0010
# Epochs 21
# 31/31 [==============================] - 40s 1s/step - loss: 0.3539 - accuracy: 0.8546 - auc: 0.9246 - precision: 0.8481 - recall: 0.8534 - val_loss: 0.4216 - val_accuracy: 0.7992 - val_auc: 0.9438 - val_precision: 0.7188 - val_recall: 0.9623 - lr: 0.0010
# Epochs 22
# 31/31 [==============================] - 41s 1s/step - loss: 0.3407 - accuracy: 0.8521 - auc: 0.9298 - precision: 0.8416 - recall: 0.8565 - val_loss: 0.3082 - val_accuracy: 0.8803 - val_auc: 0.9421 - val_precision: 0.8600 - val_recall: 0.8996 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 40s 1s/step - loss: 0.3399 - accuracy: 0.8643 - auc: 0.9308 - precision: 0.8583 - recall: 0.8628 - val_loss: 0.3278 - val_accuracy: 0.8661 - val_auc: 0.9462 - val_precision: 0.8123 - val_recall: 0.9414 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 40s 1s/step - loss: 0.3461 - accuracy: 0.8566 - auc: 0.9279 - precision: 0.8546 - recall: 0.8492 - val_loss: 0.3502 - val_accuracy: 0.8479 - val_auc: 0.9353 - val_precision: 0.8015 - val_recall: 0.9121 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 41s 1s/step - loss: 0.3355 - accuracy: 0.8632 - auc: 0.9321 - precision: 0.8641 - recall: 0.8524 - val_loss: 0.3042 - val_accuracy: 0.8600 - val_auc: 0.9501 - val_precision: 0.8125 - val_recall: 0.9247 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 23s 34ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8685064935064936
# 0.8689163668590358
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       317
#            1       0.85      0.88      0.87       299
#
#     accuracy                           0.87       616
#    macro avg       0.87      0.87      0.87       616
# weighted avg       0.87      0.87      0.87       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 6s 37ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5757575757575758
# 0.5756172839506172
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        84
#            1       0.57      0.57      0.57        81
#
#     accuracy                           0.58       165
#    macro avg       0.58      0.58      0.58       165
# weighted avg       0.58      0.58      0.58       165

# %% [markdown]
# # New Transfer Learning 0.9 Iterations = 20

# %%
valid_generator.reset()

# %%
img_size = 224
dropout_prob = 0.9
weights = "DenseNet_224_up_uncrop.h5"
iterations = 20

# %%
class CustomDropout(Layer):
    def __init__(self, dropout_prob,weights = None):
        super(CustomDropout, self).__init__()
        self.dropout_prob = dropout_prob
        self.masks = None

    def call(self, train_inputs, training=False):
        if training:
          if self.masks is not None:
            modified_object = train_inputs * self.masks
            modified_tensor = tf.convert_to_tensor(modified_object)
            return modified_tensor
        return train_inputs

# %%
base_model = DenseNet121(weights=None, include_top=False,
                                 input_shape = (img_size,img_size,3))
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout = CustomDropout(dropout_prob)
x = dropout(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))
model.load_weights(weights)
for layer in base_model.layers:
  layer.trainable = False
x = base_model.output
globa = layers.GlobalAveragePooling2D()
x = globa(x)
dropout_one = CustomDropout(dropout_prob)
x = dropout_one(x)
before_predictions = layers.Dense(128, activation='relu')
x = before_predictions(x)
dropout_two = CustomDropout(dropout_prob)
x = dropout_two(x)
predictions = layers.Dense(1, activation='sigmoid', name='last')
model = Model(inputs=base_model.input, outputs=predictions(x))

# %%
import tensorflow.keras.backend as K
print("Compiling the model...")
def get_weighted_loss(weights):
    def weighted_loss(y_true, y_pred):
        return K.mean((weights[0] ** (1 - y_true)) * (weights[1] ** y_true) * K.binary_crossentropy(y_true, y_pred), axis=-1)
    return weighted_loss
opt = Adam(lr=1e-5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=["accuracy","AUC","Precision","Recall"])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
model.summary()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = 3)
cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
num_batches_to_consider = len(valid_generator)
num_batches_to_consider

# %%
def custom_random_binomial(random_values,shape, prob, object_to_modify):
    random_values = np.broadcast_to(random_values, shape)
    mask = (random_values < (1-prob)).astype(np.float32)
    modified_object = object_to_modify * mask
    modified_tensor = tf.convert_to_tensor(modified_object)
    return modified_tensor,mask

# %%
def custom_valid_generator(generator, subset_indices):
    max_index = max(subset_indices, default=-1)
    for i, (x, y) in enumerate(generator):
        if i <= max_index:
            yield (x, y)
        else:
            return

# %%
# train the head of the network
def calculate_metric(test_y, test_preds, metric):
  if metric == "auc":
    try:
      # auc = roc_auc_score(test_y.numpy(), np.argmax(test_preds.numpy(), axis=1))
      auc = roc_auc_score(test_y.numpy(),test_preds.numpy())
      return auc
    except:
      return 0.0
    else:
      raise ValueError("Unsupported metric: " + metric)
print("training the head...")
hist_df_list = []
epochs = 25
dropout = [dropout_one,dropout_two]
for i in range(epochs):
  print(f"Epochs {i+1}")
  best_dropout_score = float("-inf")
  weight_best = None
  if dropout_prob < 0 or dropout_prob > 1:
    raise ValueError('Dropout probability has to be between 0 and 1, but got ' + str(dropout_prob))
  for iteration in range(iterations):
    np.random.seed((i+1) * iterations)
    # dropout_layer = tf.keras.layers.Dropout(dropout_prob)
    vbatch_images_array = []
    vbatch_labels_array = []
    for v_step in range(num_batches_to_consider):
      vbatch_images, vbatch_labels = valid_generator[v_step]
      vbatch_images_array.append(vbatch_images)
      vbatch_labels_array.append(vbatch_labels)
    vbatch_images = np.concatenate(vbatch_images_array)
    vbatch_labels = np.concatenate(vbatch_labels_array)

    output = globa(base_model(vbatch_images))
    shape = output.shape
    random_values_one = np.random.random(shape)[0]
    non_mask_one,mask_numpy_one = custom_random_binomial(random_values_one,shape,dropout_prob,output)
    output = before_predictions(non_mask_one)
    shape = output.shape
    random_values_two = np.random.random(shape)[0]
    non_mask_two,mask_numpy_two = custom_random_binomial(random_values_two,shape,dropout_prob,output)
    dropout_score = calculate_metric(vbatch_labels,predictions(non_mask_two),"auc")
    if dropout_score > best_dropout_score:
      best_dropout_score = dropout_score
      weight_best_one = random_values_one
      weight_best_two = random_values_two
  if weight_best is not None:
    dropout[0].masks = weight_best_one
    dropout[1].masks = weight_best_two
  model.compile(loss='binary_crossentropy', optimizer="RMSprop", metrics=["accuracy","AUC","Precision","Recall"])
  history = model.fit(
          train_generator,
          epochs = 1,
          validation_data=valid_generator,
          callbacks=[cb_checkpointer,learning_rate_reduction,cb_early_stopper],
   )
  epoch_hist_df = pd.DataFrame(history.history)
  hist_df_list.append(epoch_hist_df)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.concat(hist_df_list, ignore_index=True)
# Out:
# training the head...
# Epochs 1
# 31/31 [==============================] - 47s 1s/step - loss: 0.6853 - accuracy: 0.5785 - auc: 0.6344 - precision: 0.5763 - recall: 0.4984 - val_loss: 0.6948 - val_accuracy: 0.4848 - val_auc: 0.9127 - val_precision: 0.4848 - val_recall: 1.0000 - lr: 0.0010
# Epochs 2
# 31/31 [==============================] - 38s 1s/step - loss: 0.3563 - accuracy: 0.8551 - auc: 0.9228 - precision: 0.8439 - recall: 0.8607 - val_loss: 0.3210 - val_accuracy: 0.8560 - val_auc: 0.9413 - val_precision: 0.8182 - val_recall: 0.9038 - lr: 0.0010
# Epochs 23
# 31/31 [==============================] - 39s 1s/step - loss: 0.3364 - accuracy: 0.8582 - auc: 0.9309 - precision: 0.8514 - recall: 0.8576 - val_loss: 0.4204 - val_accuracy: 0.8073 - val_auc: 0.9349 - val_precision: 0.9235 - val_recall: 0.6569 - lr: 0.0010
# Epochs 24
# 31/31 [==============================] - 40s 1s/step - loss: 0.3330 - accuracy: 0.8627 - auc: 0.9321 - precision: 0.8498 - recall: 0.8712 - val_loss: 0.3056 - val_accuracy: 0.8722 - val_auc: 0.9481 - val_precision: 0.8359 - val_recall: 0.9163 - lr: 0.0010
# Epochs 25
# 31/31 [==============================] - 42s 1s/step - loss: 0.3286 - accuracy: 0.8643 - auc: 0.9343 - precision: 0.8517 - recall: 0.8723 - val_loss: 0.3256 - val_accuracy: 0.8661 - val_auc: 0.9436 - val_precision: 0.8100 - val_recall: 0.9456 - lr: 0.0010

# %%
plt.figure(1, figsize = (15,8))
plt.subplot(221)
plt.plot(hist_df['accuracy'])
plt.plot(hist_df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.subplot(222)
plt.plot(hist_df['loss'])
plt.plot(hist_df['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'])
plt.show()

# %%
test_generator.reset()
prediction = model.predict(test_generator)
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator)):
    batch_images, batch_labels = test_generator.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(prediction))
# Out:
# 616/616 [==============================] - 13s 19ms/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
predicted_class_indices = np.round(predicted_class_indices)
y_test = labels
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
plt.show()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.8603896103896104
# 0.8618845151556714
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86       317
#            1       0.82      0.91      0.86       299
#
#     accuracy                           0.86       616
#    macro avg       0.86      0.86      0.86       616
# weighted avg       0.87      0.86      0.86       616

# %%
model_save_path = '/content/drive/My Drive/your_folder/"ori_one_fold_new_transfer_09_20.h5"'
model.save(model_save_path)

# %%
train_generator_test.reset()
valid_generator_test.reset()
test_generator_test.reset()
combined_prediction = []
combined_prediction.extend(model.predict(test_generator_test))
images = []
labels = []
predicted_class_indices = []
for i in range(len(test_generator_test)):
    batch_images, batch_labels = test_generator_test.next()
    images.extend(batch_images)
    labels.extend(batch_labels)
images = np.array(images)
labels = np.array(labels)
predicted_class_indices = np.round(np.array(combined_prediction))
from sklearn.metrics import confusion_matrix, accuracy_score, auc, roc_auc_score, classification_report
y_test = labels.T
print(plot_confusion_matrix(confusion_matrix(y_test, predicted_class_indices), figsize=(5,5)))
print(accuracy_score(y_test, predicted_class_indices))
print(roc_auc_score(y_test, predicted_class_indices, multi_class='ovr'))
print(classification_report(y_test, predicted_class_indices))
# Out:
# 165/165 [==============================] - 4s 21ms/step
# (<Figure size 500x500 with 1 Axes>, <Axes: xlabel='predicted label', ylabel='true label'>)
# 0.5515151515151515
# 0.5524691358024691
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        84
#            1       0.54      0.60      0.57        81
#
#     accuracy                           0.55       165
#    macro avg       0.55      0.55      0.55       165
# weighted avg       0.55      0.55      0.55       165
